# %%
import os
from typing import Annotated

from fastapi import APIRouter, status
from fastapi.params import Query

from bdi_api.settings import Settings

import requests
import os

# %%
# Exemplo mínimo para teste
flights_teste = {
    "ac": [
        {
            "lat": -23.5505,
            "lon": -46.6333,
            "flight": "TAM1234",
            "alt_baro": 35000
        },
        {
            "lat": -23.6505,
            "lon": -46.7333,
            "flight": "GOL5678",
            "alt_baro": 28000
        }
    ]
}

# Criar e salvar o mapa
map_flights = create_flight_map(flights_teste)
map_flights.save('flights_visualizations/flights_visualizations/flights_map.html')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[20], line 20
#       2 flights_teste = {
#       3     "ac": [
#       4         {
#    (...)
#      16     ]
#      17 }
#      19 # Criar e salvar o mapa
# ---> 20 map_flights = create_flight_map(flights_teste)
#      21 map_flights.save('flights_visualizations/flights_visualizationsflights_map.html')
#
# Cell In[17], line 6, in create_flight_map(flights_data)
#       2 """
#       3 Cria um mapa com os voos usando Folium
#       4 """
#       5 # Calcular centro do mapa baseado na média das coordenadas
# ----> 6 lats = [flight['lat'] for flight in flights_data['aircraft'] if 'lat' in flight]
#       7 lons = [flight['lon'] for flight in flights_data['aircraft'] if 'lon' in flight]
#       9 if lats and lons:  # Verificar se há coordenadas válidas
#
# KeyError: 'aircraft'

# %%
def create_flight_map(flights_data):
    """
    Cria um mapa com os voos usando Folium
    """
    # Calcular centro do mapa baseado na média das coordenadas
    lats = [flight['lat'] for flight in flights_data['aircraft'] if 'lat' in flight]
    lons = [flight['lon'] for flight in flights_data['aircraft'] if 'lon' in flight]
    
    if lats and lons:  # Verificar se há coordenadas válidas
        center_lat = sum(lats) / len(lats)
        center_lon = sum(lons) / len(lons)
    else:
        # Coordenadas padrão caso não haja dados válidos
        center_lat, center_lon = 0, 0

    # Criar mapa
    flight_map = folium.Map(location=[center_lat, center_lon], zoom_start=6)
    
    # Adicionar marcadores para cada voo
    for flight in flights_data['aircraft']:
        if 'lat' in flight and 'lon' in flight:
            # Criar popup com informações do voo
            popup_text = f"""
            Flight: {flight.get('flight', 'N/A')}
            Altitude: {flight.get('alt_baro', 'N/A')} ft
            Speed: {flight.get('gs', 'N/A')} kts
            Aircraft: {flight.get('t', 'N/A')}
            """
            
            folium.Marker(
                [flight['lat'], flight['lon']],
                popup=popup_text,
                icon=folium.Icon(color='red', icon='plane', prefix='fa')
            ).add_to(flight_map)
    
    return flight_map

# %%
import json


def read_flights_data(file_path):
    """
    Lê um arquivo JSON contendo dados de voos e retorna seu conteúdo.
    
    Parâmetros:
        file_path (str): Caminho para o arquivo JSON
        
    Retorna:
        dict: Dicionário contendo os dados dos voos
    """
    try:
        # Abrimos o arquivo em modo texto ('r') com codificação UTF-8
        with open(file_path, 'r', encoding='utf-8') as file:
            # json.load() converte o conteúdo JSON em um objeto Python
            data = json.load(file)
            return data
            
    except FileNotFoundError:
        # Caso o arquivo não seja encontrado
        print(f"Erro: O arquivo {file_path} não foi encontrado.")
        raise
        
    except json.JSONDecodeError:
        # Caso o arquivo não seja um JSON válido
        print(f"Erro: O arquivo {file_path} não contém um JSON válido.")
        raise
        
    except Exception as e:
        # Para outros tipos de erro que possam ocorrer
        print(f"Erro inesperado ao ler o arquivo: {str(e)}")
        raise

# %%
flights_data = read_flights_data('data/000010Z.json.gz')

flights_data
# Out:
# {'now': 1698796809.3,
#  'messages': 1105437409,
#  'aircraft': [{'hex': 'a65800',
#    'type': 'adsc',
#    'flight': 'DL295   ',
#    'r': 'N508DN',
#    't': 'A359',
#    'alt_baro': 39996,
#    'gs': 454.0,
#    'track': 244.71,
#    'baro_rate': -16,
#    'lat': 46.57774,
#    'lon': -178.413162,
#    'nic': 0,
#    'rc': 0,
#    'seen_pos': 200.091,
#    'alert': 0,
#    'spi': 0,
#    'mlat': [],
#    'tisb': [],
#    'messages': 31181264,
#    'seen': 200.1,
#    'rssi': -49.5},
#   {'hex': 'ab5c12',
#    'type': 'adsc',
#    'flight': 'AA281   ',
#    'r': 'N831AA',
#    't': 'B789',
#    'alt_baro': 37004,
#    'gs': 450.0,
#    'track': 254.26,
#    'baro_rate': -16,
#    'lat': 46.60675,
#    'lon': -177.535114,
#    'nic': 0,
#    'rc': 0,
#    'seen_pos': 42.497,
#    'alert': 0,
#    'spi': 0,
#    'mlat': [],
#    'tisb': [],
#    'messages': 35005653,
#    'seen': 42.5,
#    'rssi': -49.5},
#   {'hex': '76cdb7',
#    'type': 'adsc',
#    'flight': 'SQ31    ',
#    'r': '9V-SMW',
#    't': 'A359',
#    'alt_baro': 38000,
#    'gs': 442.0,
#    'track': 251.77,
#    'baro_rate': 0,
#    'lat': 44.549732,
#    'lon': -174.605541,
#    'nic': 0,
#    'rc': 0,
#    'seen_pos': 830.29,
#    'alert': 0,
#    'spi': 0,
#    'mlat': [],
#    'tisb': [],
#    'messages': 24602633,
#    'seen': 830.3,
#    'rssi': -49.5},
#   {'hex': '71be24',
#    'type': 'adsc',
#    'flight': 'KE213D  ',
#    'r': 'HL7624',
#    't': 'B748',
#    'alt_baro': 33000,
#    'gs': 550.0,
#    'track': 78.36,
#    'baro_rate': 0,
#    'lat': 36.651077,
#    'lon': -174.561596,
#    'nic': 0,
#    'rc': 0,
#    'seen_pos': 24.245,
#    'alert': 0,
#    'spi': 0,
#    'mlat': [],
#    'tisb': [],
#    'messages': 28573953,
#    'seen': 24.2,
#    'rssi': -49.5},
#   {'hex': '86e058',
#    'type': 'adsc',
#    'flight': 'ZG23    ',
#    'r': 'JA851J',
#    't': 'B788',
#    'alt_baro': 40004,
#    'gs': 447.0,
#    'track': 255.92,
#    'baro_rate': -32,
#    'lat': 44.214821,
#    'lon': -174.551983,
#    'nic': 0,
#    'rc': 0,
#    'seen_pos': 932.433,
#    'alert': 0,
#    'spi': 0,
#    'mlat': [],
#    'tisb': [],
#    'messages': 7891586,
#    'seen': 932.4,
#    'rssi': -49.5},
#   {'hex': '71c387',
#    'type': 'adsc',
#    'flight': 'YP102   ',
#    'r': 'HL8387',
#    't': 'B789',
#    'alt_baro': 35996,
#    'gs': 440.0,
#    'track': 248.52,
#    'baro_rate': 0,
#    'lat': 46.99831,
#    'lon': -173.809547,
#    'nic': 0,
#    'rc': 0,
#    'seen_pos': 1184.102,
#    'alert': 0,
#    'spi': 0,
#    'mlat': [],
#    'tisb': [],
#    'messages': 23809171,
#    'seen': 1184.1,
#    'rssi': -49.5},
#   {'hex': 'c038aa',
#    'type': 'adsc',
#    'flight': 'AC7     ',
#    'r': 'C-FVLX',
#    't': 'B789',
#    'alt_baro': 34996,
#    'gs': 429.0,
#    'track': 256.28,
#    'baro_rate': 32,
#    'lat': 45.37405,
#    'lon': -173.720284,
#    'nic': 0,
#    'rc': 0,
#    'seen_pos': 951.039,
#    'alert': 0,
#    'spi': 0,
#    'mlat': [],
#    'tisb': [],
#    'messages': 38995004,
#    'seen': 951.0,
#    'rssi': -49.5},
#   {'hex': 'c02ec1',
#    'type': 'adsc',
#    'flight': 'AC25    ',
#    'r': 'C-FRSI',
#    't': 'B789',
#    'alt_baro': 35996,
#    'gs': 435.0,
#    'track': 247.71,
#    'baro_rate': 0,
#    'lat': 45.388641,
#    'lon': -173.641319,
#    'nic': 0,
#    'rc': 0,
#    'seen_pos': 455.708,
#    'alert': 0,
#    'spi': 0,
#    'mlat': [],
#    'tisb': [],
#    'messages': 35764152,
#    'seen': 455.7,
#    'rssi': -49.5},
#   {'hex': 'ab1bf0',
#    'type': 'adsc',
#    'flight': 'AA127   ',
#    'r': 'N815AA',
#    't': 'B788',
#    'alt_baro': 38996,
#    'gs': 461.0,
#    'track': 258.55,
#    'baro_rate': 0,
#    'lat': 47.647362,
#    'lon': -172.19593,
#    'nic': 0,
#    'rc': 0,
#    'seen_pos': 749.311,
#    'alert': 0,
#    'spi': 0,
#    'mlat': [],
#    'tisb': [],
#    'messages': 34516026,
#    'seen': 749.3,
#    'rssi': -49.5},
#   {'hex': 'a31a54',
#    'type': 'adsc',
#    'flight': 'UA29    ',
#    'r': 'N29975',
#    't': 'B789',
#    'alt_baro': 33988,
#    'gs': 463.0,
#    'track': 249.67,
#    'baro_rate': 32,
#    'lat': 48.472195,
#    'lon': -172.08744,
#    'nic': 0,
#    'rc': 0,
#    'seen_pos': 1133.281,
#    'alert': 0,
#    'spi': 0,
#    'mlat': [],
#    'tisb': [],
#    'messages': 32311681,
#    'seen': 1133.3,
#    'rssi': -49.5},
#   {'hex': 'aad012',
#    'type': 'adsc',
#    'flight': 'UA131   ',
#    'r': 'N796UA',
#    't': 'B772',
#    'alt_baro': 34000,
#    'gs': 474.0,
#    'track': 248.36,
#    'baro_rate': 0,
#    'lat': 50.626202,
#    'lon': -171.115665,
#    'nic': 0,
#    'rc': 0,
#    'seen_pos': 1511.076,
#    'alert': 0,
#    'spi': 0,
#    'mlat': [],
#    'tisb': [],
#    'messages': 42697055,
#    'seen': 1511.1,
#    'rssi': -49.5},
#   {'hex': 'a31a34',
#    'type': 'adsc',
#    'flight': 'UA28    ',
#    'r': 'N29968',
#    't': 'B789',
#    'alt_baro': 38004,
#    'gs': 589.0,
#    'track': 91.78,
#    'baro_rate': -48,
#    'lat': 34.035988,
#    'lon': -170.981941,
#    'nic': 0,
#    'rc': 0,
#    'seen_pos': 238.33,
#    'alert': 0,
#    'spi': 0,
#    'mlat': [],
#    'tisb': [],
#    'messages': 33630817,
#    'seen': 238.3,
#    'rssi': -49.5},
#   {'hex': '71c005',
#    'type': 'adsc',
#    'flight': 'KE277   ',
#    'r': 'HL8005',
#    't': 'B77L',
#    'alt_baro': 35000,
#    'gs': 485.0,
#    'track': 45.03,
#    'baro_rate': 16,
#    'lat': 51.447258,
#    'lon': -170.953789,
#    'nic': 0,
#    'rc': 0,
#    'seen_pos': 162.774,
#    'alert': 0,
#    'spi': 0,
#    'mlat': [],
#    'tisb': [],
#    'messages': 25577380,
#    'seen': 162.8,
#    'rssi': -49.5},
#   {'hex': 'a2a3af',
#    'type': 'adsc',
#    'flight': 'UA801   ',
#    'r': 'N26960',
#    't': 'B789',
#    'alt_baro': 35836,
#    'gs': 446.0,
#    'track': 257.86,
#    'baro_rate': 1104,
#    'lat': 44.854088,
#    'lon': -170.941086,
#    'nic': 0,
#    'rc': 0,
#    'seen_pos': 833.322,
#    'alert': 0,
#    'spi': 0,
#    'mlat': [],
#    'tisb': [],
#    'messages': 33004660,
#    'seen': 833.3,
#    'rssi': -49.5},
#   {'hex': '71c347',
#    'type': 'adsc',
#    'flight': 'KE42    ',
#    'r': 'HL8347',
#    't': 'B77W',
#    'alt_baro': 34000,
#    'gs': 467.0,
#    'track': 243.31,
#    'baro_rate': 0,
#    'lat': 49.785404,
#    'lon': -170.645142,
#    'nic': 0,
#    'rc': 0,
#    'seen_pos': 806.779,
#    'alert': 0,
#    'spi': 0,
#    'mlat': [],
#    'tisb': [],
#    'messages': 24160443,
#    'seen': 806.8,
#    'rssi': -49.5},
#   {'hex': 'ac2cb2',
#    'type': 'adsc',
#    'flight': 'AA27    ',
#    'r': 'N884AA',
#    't': 'B788',
#    'alt_baro': 37992,
#    'gs': 456.0,
#    'track': 268.23,
#    'baro_rate': 16,
#    'lat': 43.990116,
#    'lon': -170.177021,
#    'nic': 0,
#    'rc': 0,
#    'seen_pos': 837.239,
#    'alert': 0,
#    'spi': 0,
#    'mlat': [],
#    'tisb': [],
#    'messages': 34519665,
#    'seen': 837.2,
#    'rssi': -49.5},
#   {'hex': '86e84c',
#    'type': 'adsc',
#    'flight': 'JL791   ',
#    'r': 'JA877J',
#    't': 'B789',
#    'alt_baro': 39004,
#    'track': 279.64,
#    'lat': 22.018833,
#    'lon': -170.144234,
#    'nic': 0,
#    'rc': 0,
#    'seen_pos': 1625.977,
#    'alert': 0,
#    'spi': 0,
#    'mlat': [],
#    'tisb': [],
#    'messages': 21075074,
#    'seen': 1626.0,
#    'rssi': -49.5},
#   {'hex': 'ad4482',
#    'type': 'adsb_icao',
#    'flight': 'BRG853  ',
#    'r': 'N954LE',
#    't': 'B190',
#    'alt_baro': 24000,
#    'alt_geom': 23300,
#    'gs': 208.1,
#    'track': 257.23,
#    'baro_rate': -128,
#    'squawk': '5104',
#    'emergency': 'none',
#    'category': 'A2',
#    'nav_qnh': 1013.6,
#    'nav_altitude_mcp': 6016,
#    'lat': 64.177322,
#    'lon': -169.218926,
#    'nic': 9,
#    'rc': 75,
#    'seen_pos': 4.102,
#    'version': 2,
#    'nic_baro': 1,
#    'nac_p': 10,
#    'nac_v': 2,
#    'sil': 3,
#    'sil_type': 'perhour',
#    'gva': 2,
#    'sda': 2,
#    'alert': 0,
#    'spi': 0,
#    'mlat': [],
#    'tisb': [],
#    'messages': 230525,
#    'seen': 0.4,
#    'rssi': -29.7},
#   {'hex': 'a1f1a0',
#    'type': 'adsc',
#    'flight': 'UA837   ',
#    'r': 'N224UA',
#    't': 'B772',
#    'alt_baro': 34000,
#    'gs': 458.0,
#    'track': 245.82,
#    'baro_rate': 0,
#    'lat': 45.330448,
#    'lon': -169.07238,
#    'nic': 0,
#    'rc': 0,
#    'seen_pos': 672.143,
#    'alert': 0,
#    'spi': 0,
#    'mlat': [],
#    'tisb': [],
#    'messages': 38291004,
#    'seen': 672.1,
#    'rssi': -49.5},
#   {'hex': 'aa781f',
#    'type': 'adsc',
#    'flight': 'K40260  ',
#    'r': 'N774CK',
#    't': 'B77L',
#    'alt_baro': 34000,
#    'gs': 454.0,
#    'track': 264.5,
#    'baro_rate': 0,
#    'lat': 45.228825,
#    'lon': -168.347111,
#    'nic': 0,
#    'rc': 0,
#    'seen_pos': 222.961,
#    'alert': 0,
#    'spi': 0,
#    'mlat': [],
#    'tisb': [],
#    'messages': 30422689,
#    'seen': 223.0,
#    'rssi': -49.5},
#   {'hex': 'a07dcd',
#    'type': 'adsc',
#    'flight': 'UA32    ',
#    'r': 'N13018',
#    't': 'B78X',
#    'alt_baro': 37996,
#    'gs': 475.0,
#    'track': 247.28,
#    'baro_rate': 16,
#    'lat': 45.969887,
#    'lon': -167.236633,
#    'nic': 0,
#    'rc': 0,
#    'seen_pos': 797.287,
#    'alert': 0,
#    'spi': 0,
#    'mlat': [],
#    'tisb': [],
#    'messages': 48361450,
#    'seen': 797.3,
#    'rssi': -49.5},
#   {'hex': '769101',
#    'type': 'adsc',
#    'flight': 'SQ7429  ',
#    'r': '9V-DHA',
#    't': 'B77L',
#    'alt_baro': 34000,
#    'gs': 476.0,
#    'track': 231.52,
#    'baro_rate': 32,
#    'lat': 12.763882,
#    'lon': -167.044716,
#    'nic': 0,
#    'rc': 0,
#    'seen_pos': 275.747,
#    'alert': 0,
#    'spi': 0,
#    'mlat': [],
#    'tisb': [],
#    'messages': 17475699,
#    'seen': 275.7,
#    'rssi': -49.5},
#   {'hex': 'aa6b9d',
#    'type': 'adsc',
#    'flight': 'UA35    ',
#    'r': 'N77012',
#    't': 'B772',
#    'alt_baro': 33996,
#    'gs': 464.0,
#    'track': 246.37,
#    'baro_rate': 0,
#    'lat': 46.107388,
#    'lon': -166.755295,
#    'nic': 0,
#    'rc': 0,
#    'seen_pos': 523.473,
#    'alert': 0,
#    'spi': 0,
#    'mlat': [],
#    'tisb': [],
#    'messages': 40144344,
#    'seen': 523.5,
#    'rssi': -49.5},
#   {'hex': 'c02ee9',
#    'type': 'adsc',
#    'flight': 'AC63    ',
#    'r': 'C-FRTW',
#    't': 'B789',
#    'alt_baro': 33996,
#    'gs': 495.0,
#    'track': 240.31,
#    'baro_rate': 0,
#    'lat': 48.128529,
#    'lon': -165.145283,
#    'nic': 0,
#    'rc': 0,
#    'seen_pos': 985.409,
#    'alert': 0,
#    'spi': 0,
#    'mlat': [],
#    'tisb': [],
#    'messages': 38860269,
#    'seen': 985.4,
#    'rssi': -49.5},
#   {'hex': 'a43fa0',
#    'type': 'adsc',
#    'flight': 'HA821   ',
#    'r': 'N373HA',
#    't': 'A332',
#    'alt_baro': 38000,
#    'gs': 474.0,
#    'track': 268.0,
#    'baro_rate': 0,
#    'category': 'A5',
#    'lat': 21.161041,
#    'lon': -163.595352,
#    'nic': 0,
#    'rc': 0,
#    'seen_pos': 602.532,
#    'alert': 0,
#    'spi': 0,
#    'mlat': [],
#    'tisb': [],
#    'messages': 24121292,
#    'seen': 602.5,
#    'rssi': -49.5},
#   {'hex': 'aa92f9',
#    'type': 'adsc',
#    'flight': 'UA7     ',
#    'r': 'N78002',
#    't': 'B772',
#    'alt_baro': 37000,
#    'gs': 477.0,
#    'track': 257.13,
#    'baro_rate': -16,
#    'lat': 48.588581,
#    'lon': -162.537746,
#    'nic': 0,
#    'rc': 0,
#    'seen_pos': 261.258,
#    'alert': 0,
#    'spi': 0,
#    'mlat': [],
#    'tisb': [],
#    'messages': 39844621,
#    'seen': 261.3,
#    'rssi': -49.5},
#   {'hex': 'a50aae',
#    'type': 'adsr_icao',
#    'flight': 'N424CA  ',
#    'r': 'N424CA',
#    't': 'C212',
#    'alt_baro': 700,
#    'alt_geom': 675,
#    'gs': 155.0,
#    'track': 289.6,
#    'baro_rate': -128,
#    'squawk': '1200',
#    'emergency': 'none',
#    'category': 'A1',
#    'lat': 60.900421,
#    'lon': -162.330385,
#    'nic': 0,
#    'rc': 0,
#    'seen_pos': 0.258,
#    'nac_v': 0,
#    'alert': 0,
#    'spi': 0,
#    'mlat': [],
#    'tisb': [],
#    'messages': 1505238,
#    'seen': 0.2,
#    'rssi': -3.1},
#   {'hex': 'a47439',
#    'type': 'adsr_icao',
#    'flight': 'N3862G  ',
#    'r': 'N3862G',
#    't': 'T206',
#    'alt_geom': 525,
#    'gs': 117.1,
#    'track': 121.38,
#    'baro_rate': 0,
#    'squawk': '1200',
#    'emergency': 'none',
#    'category': 'A1',
#    'lat': 60.854553,
#    'lon': -162.207357,
#    'nic': 0,
#    'rc': 0,
#    'seen_pos': 1.691,
#    'nac_v': 0,
#    'sil_type': 'perhour',
#    'alert': 0,
#    'spi': 0,
#    'mlat': [],
#    'tisb': [],
#    'messages': 3016287,
#    'seen': 1.7,
#    'rssi': -7.3},
#   {'hex': 'aa0e2a',
#    'type': 'adsr_icao',
#    'flight': 'YCS7SQ  ',
#    'r': 'N747SQ',
#    't': 'C207',
#    'alt_baro': 600,
#    'alt_geom': 650,
#    'gs': 108.4,
#    'track': 29.88,
#    'baro_rate': -64,
#    'squawk': '1200',
#    'emergency': 'none',
#    'category': 'A1',
#    'lat': 60.496628,
#    'lon': -162.19353,
#    'nic': 0,
#    'rc': 0,
#    'seen_pos': 0.258,
#    'nac_v': 0,
#    'sil_type': 'perhour',
#    'alert': 0,
#    'spi': 0,
#    'mlat': [],
#    'tisb': [],
#    'messages': 2610343,
#    'seen': 0.3,
#    'rssi': -2.4},
#   {'hex': 'a81992',
#    'type': 'adsr_icao',
#    'flight': 'YCS07H  ',
#    'r': 'N6207H',
#    't': 'C207',
#    'alt_baro': 600,
#    'alt_geom': 675,
#    'gs': 101.0,
#    'track': 33.69,
#    'baro_rate': -320,
#    'squawk': '1200',
#    'emergency': 'none',
#    'category': 'A1',
#    'lat': 60.494568,
#    'lon': -162.192962,
#    'nic': 0,
#    'rc': 0,
#    'seen_pos': 0.258,
#    'nac_v': 0,
#    'sil_type': 'perhour',
#    'alert': 0,
#    'spi': 0,
#    'mlat': [],
#    'tisb': [],
#    'messages': 2915994,
#    'seen': 0.3,
#    'rssi': 0.0},
#   {'hex': 'a4005f',
#    'type': 'tisb_icao',
#    'flight': 'N357SA  ',
#    'r': 'N357SA',
#    't': 'PA31',
#    'alt_baro': 2100,
#    'alt_geom': 2250,
#    'gs': 152.9,
#    'track': 305.15,
#    'baro_rate': 640,
#    'geom_rate': 704,
#    'squawk': '1200',
#    'emergency': 'none',
#    'category': 'A1',
#    'lat': 60.904404,
#    'lon': -162.176198,
#    'nic': 0,
#    'rc': 0,
#    'seen_pos': 0.258,
#    'version': 2,
#    'nic_baro': 0,
#    'nac_p': 0,
#    'nac_v': 2,
#    'sil': 0,
#    'sil_type': 'perhour',
#    'gva': 2,
#    'sda': 2,
#    'alert': 0,
#    'spi': 0,
#    'mlat': [],
#    'tisb': ['callsign',
#     'altitude',
#     'alt_geom',
#     'baro_rate',
#     'lat',
#     'lon',
#     'nic',
#     'rc',
#     'nac_p',
#     'sil',
#     'sil_type'],
#    'messages': 2297077,
#    'seen': 0.3,
#    'rssi': 0.0},
#   {'hex': 'ab148e',
#    'type': 'adsc',
#    'flight': 'AA61    ',
#    'r': 'N813AN',
#    't': 'B788',
#    'alt_baro': 36000,
#    'gs': 497.0,
#    'track': 242.65,
#    'baro_rate': 0,
#    'lat': 49.256001,
#    'lon': -162.169018,
#    'nic': 0,
#    'rc': 0,
#    'seen_pos': 879.087,
#    'alert': 0,
#    'spi': 0,
#    'mlat': [],
#    'tisb': [],
#    'messages': 30425893,
#    'seen': 879.1,
#    'rssi': -49.5},
#   {'hex': 'a9e89e',
#    'type': 'adsr_icao',
#    'flight': 'RYA789  ',
#    'r': 'N73789',
#    't': 'C207',
#    'alt_baro': 425,
#    'alt_geom': 525,
#    'gs': 101.9,
#    'track': 42.61,
#    'baro_rate': -128,
#    'squawk': '1200',
#    'emergency': 'none',
#    'category': 'A1',
#    'lat': 60.533752,
#    'lon': -162.076847,
#    'nic': 0,
#    'rc': 0,
#    'seen_pos': 0.576,
#    'nac_v': 0,
#    'sil_type': 'perhour',
#    'alert': 0,
#    'spi': 0,
#    'mlat': [],
#    'tisb': [],
#    'messages': 826114,
#    'seen': 0.6,
#    'rssi': -0.6},
#   {'hex': 'a97775',
#    'type': 'adsb_icao',
#    'flight': 'RYA709  ',
#    'r': 'N709RA',
#    't': 'C208',
#    'alt_baro': 1675,
#    'alt_geom': 1725,
#    'gs': 133.4,
#    'track': 23.88,
#    'baro_rate': 0,
#    'geom_rate': 0,
#    'squawk': '5136',
#    'emergency': 'none',
#    'category': 'A1',
#    'nav_qnh': 1017.6,
#    'nav_altitude_mcp': 1792,
#    'lat': 60.657193,
#    'lon': -161.944951,
#    'nic': 9,
#    'rc': 75,
#    'seen_pos': 0.17,
#    'version': 2,
#    'nic_baro': 1,
#    'nac_p': 10,
#    'nac_v': 2,
#    'sil': 3,
#    'sil_type': 'perhour',
#    'gva': 2,
#    'sda': 2,
#    'alert': 0,
#    'spi': 0,
#    'mlat': [],
#    'tisb': ['geom_rate'],
#    'messages': 3196736,
#    'seen': 0.2,
#    'rssi': -5.1},
#   {'hex': '71be34',
#    'type': 'adsc',
#    'flight': 'OZ201   ',
#    'r': 'HL7634',
#    't': 'A388',
#    'alt_baro': 34000,
#    'gs': 515.0,
#    'track': 256.67,
#    'baro_rate': -16,
#    'lat': 50.73658,
#    'lon': -161.670513,
#    'nic': 0,
#    'rc': 0,
#    'seen_pos': 511.272,
#    'alert': 0,
#    'spi': 0,
#    'mlat': [],
#    'tisb': [],
#    'messages': 5260109,
#    'seen': 511.3,
#    'rssi': -49.5},
#   {'hex': '06a1cd',
#    'type': 'adsb_icao',
#    'flight': 'QQE508  ',
#    'r': 'A7-CGH',
#    't': 'GLF6',
#    'alt_baro': 43000,
#    'alt_geom': 42525,
#    'gs': 479.5,
#    'track': 282.04,
#    'baro_rate': 0,
#    'squawk': '7054',
#    'emergency': 'none',
#    'category': 'A3',
#    'nav_qnh': 1013.6,
#    'nav_altitude_mcp': 43008,
#    'nav_modes': ['autopilot', 'althold', 'tcas'],
#    'lat': 60.182098,
#    'lon': -161.60775,
#    'nic': 8,
#    'rc': 186,
#    'seen_pos': 0.651,
#    'version': 2,
#    'nic_baro': 1,
#    'nac_p': 10,
#    'nac_v': 2,
#    'sil': 3,
#    'sil_type': 'perhour',
#    'gva': 2,
#    'sda': 2,
#    'alert': 0,
#    'spi': 0,
#    'mlat': [],
#    'tisb': [],
#    'messages': 8584521,
#    'seen': 0.4,
#    'rssi': -19.5},
#   {'hex': '71c007',
#    'type': 'adsc',
#    'flight': 'KE38    ',
#    'r': 'HL8007',
#    't': 'B77W',
#    'alt_baro': 34000,
#    'gs': 527.0,
#    'track': 257.69,
#    'baro_rate': 0,
#    'lat': 51.881561,
#    'lon': -160.770664,
#    'nic': 0,
#    'rc': 0,
#    'seen_pos': 1964.276,
#    'alert': 0,
#    'spi': 0,
#    'mlat': [],
#    'tisb': [],
#    'messages': 24458000,
#    'seen': 1964.3,
#    'rssi': -49.5},
#   {'hex': '86e778',
#    'type': 'adsc',
#    'flight': 'NH113   ',
#    'r': 'JA871A',
#    't': 'B789',
#    'alt_baro': 38000,
#    'gs': 503.0,
#    'track': 243.27,
#    'baro_rate': 0,
#    'lat': 49.763947,
#    'lon': -160.708179,
#    'nic': 0,
#    'rc': 0,
#    'seen_pos': 1166.014,
#    'alert': 0,
#    'spi': 0,
#    'mlat': [],
#    'tisb': [],
#    'messages': 26832548,
#    'seen': 1166.0,
#    'rssi': -49.5},
#   {'hex': '71ba06',
#    'type': 'adsc',
#    'flight': 'KE74    ',
#    'r': 'HL7206',
#    't': 'B789',
#    'alt_baro': 34000,
#    'gs': 537.0,
#    'track': 260.13,
#    'baro_rate': 0,
#    'lat': 51.977005,
#    'lon': -160.151825,
#    'nic': 0,
#    'rc': 0,
#    'seen_pos': 409.506,
#    'alert': 0,
#    'spi': 0,
#    'mlat': [],
#    'tisb': [],
#    'messages': 27004487,
#    'seen': 409.5,
#    'rssi': -49.5},
#   {'hex': '71be21',
#    'type': 'adsc',
#    'flight': 'KE18    ',
#    'r': 'HL7621',
#    't': 'A388',
#    'alt_baro': 38008,
#    'gs': 504.0,
#    'track': 266.39,
#    'baro_rate': -16,
#    'lat': 50.999565,
#    'lon': -160.014839,
#    'nic': 0,
#    'rc': 0,
#    'seen_pos': 863.379,
#    'alert': 0,
#    'spi': 0,
#    'mlat': [],
#    'tisb': [],
#    'messages': 18894974,
#    'seen': 863.4,
#    'rssi': -49.5},
#   {'hex': 'a2cb13',
#    'type': 'adsc',
#    'flight': 'UA79    ',
#    'r': 'N27958',
#    't': 'B789',
#    'alt_baro': 36000,
#    'gs': 532.0,
#    'track': 259.53,
#    'baro_rate': 16,
#    'lat': 52.000866,
#    'lon': -160.012779,
#    'nic': 0,
#    'rc': 0,
#    'seen_pos': 1.485,
#    'alert': 0,
#    'spi': 0,
#    'mlat': [],
#    'tisb': [],
#    'messages': 28943435,
#    'seen': 1.5,
#    'rssi': -49.5},
#   {'hex': 'a31a56',
#    'type': 'adsc',
#    'flight': 'UA143   ',
#    'r': 'N29977',
#    't': 'B789',
#    'alt_baro': 35996,
#    'gs': 501.0,
#    'track': 259.31,
#    'baro_rate': -16,
#    'lat': 47.996693,
#    'lon': -160.006256,
#    'nic': 0,
#    'rc': 0,
#    'seen_pos': 447.632,
#    'alert': 0,
#    'spi': 0,
#    'mlat': [],
#    'tisb': [],
#    'messages': 19767371,
#    'seen': 447.6,
#    'rssi': -49.5},
#   {'hex': '75827b',
#    'type': 'adsc',
#    'flight': 'PR113   ',
#    'r': 'RP-C7773',
#    't': 'B77W',
#    'alt_baro': 32000,
#    'gs': 527.0,
#    'track': 276.16,
#    'baro_rate': 0,
#    'lat': 51.994171,
#    'lon': -160.005569,
#    'nic': 0,
#    'rc': 0,
#    'seen_pos': 146.959,
#    'alert': 0,
#    'spi': 0,
#    'mlat': [],
#    'tisb': [],
#    'messages': 12390576,
#    'seen': 147.0,
#    'rssi': -49.5},
#   {'hex': '867ff0',
#    'type': 'adsc',
#    'flight': 'JL11    ',
#    'r': 'JA735J',
#    't': 'B77W',
#    'alt_baro': 31996,
#    'track': 259.77,
#    'lat': 49.995174,
#    'lon': -160.002308,
#    'nic': 0,
#    'rc': 0,
#    'seen_pos': 1805.125,
#    'alert': 0,
#    'spi': 0,
#    'mlat': [],
#    'tisb': [],
#    'messages': 21595306,
#    'seen': 1805.1,
#    'rssi': -49.5},
#   {'hex': '899125',
#    'type': 'adsc',
#    'flight': 'CI32    ',
#    'r': 'B-18908',
#    't': 'A359',
#    'alt_baro': 41000,
#    'gs': 506.0,
#    'track': 76.73,
#    'baro_rate': 0,
#    'lat': 47.001915,
#    'lon': -159.985313,
#    'nic': 0,
#    'rc': 0,
#    'seen_pos': 683.488,
#    'alert': 0,
#    'spi': 0,
#    'mlat': [],
#    'tisb': [],
#    'messages': 28026922,
#    'seen': 683.5,
#    'rssi': -49.5},
#   {'hex': 'ac7e18',
#    'type': 'adsb_icao',
#    'flight': 'KYE4872 ',
#    'r': 'N904AR',
#    't': 'B744',
#    'alt_baro': 33000,
#    'alt_geom': 32625,
#    'calc_track': 74,
#    'category': 'A0',
#    'lat': 59.845596,
#    'lon': -159.881378,
#    'nic': 10,
#    'rc': 25,
#    'seen_pos': 60.751,
#    'version': 0,
#    'nac_p': 10,
#    'sil': 2,
#    'sil_type': 'unknown',
#    'alert': 0,
#    'spi': 0,
#    'mlat': [],
#    'tisb': [],
#    'messages': 20904633,
#    'seen': 13.3,
#    'rssi': -22.5},
#   {'hex': 'a4cf0d',
#    'type': 'adsb_icao',
#    'flight': 'LYC409  ',
#    'r': 'N409LC',
#    't': 'C130',
#    'alt_baro': 27000,
#    'alt_geom': 26775,
#    'gs': 349.5,
#    'track': 98.06,
#    'baro_rate': 256,
#    'squawk': '2253',
#    'emergency': 'none',
#    'category': 'A3',
#    'nav_qnh': 1013.6,
#    'nav_altitude_mcp': 27008,
#    'lat': 61.840256,
#    'lon': -159.723751,
#    'nic': 8,
#    'rc': 186,
#    'seen_pos': 0.396,
#    'version': 2,
#    'nic_baro': 1,
#    'nac_p': 10,
#    'nac_v': 2,
#    'sil': 3,
#    'sil_type': 'perhour',
#    'gva': 2,
#    'sda': 2,
#    'alert': 0,
#    'spi': 0,
#    'mlat': [],
#    'tisb': [],
#    'messages': 8149552,
#    'seen': 0.4,
#    'rssi': -26.0},
#   {'hex': 'a57682',
#    'type': 'tisb_icao',
#    'flight': 'N451H   ',
#    'r': 'N451H',
#    't': 'AS50',
#    'alt_baro': 2600,
#    'alt_geom': 2725,
#    'gs': 118.2,
#    'track': 299.38,
#    'baro_rate': 0,
#    'category': 'A7',
#    'lat': 22.031754,
#    'lon': -159.604531,
#    'nic': 0,
#    'rc': 0,
#    'seen_pos': 0.716,
#    'version': 0,
#    'nac_p': 0,
#    'nac_v': 0,
#    'sil': 0,
#    'sil_type': 'perhour',
#    'alert': 0,
#    'spi': 0,
#    'mlat': [],
#    'tisb': ['callsign',
#     'altitude',
#     'alt_geom',
#     'gs',
#     'track',
#     'baro_rate',
#     'lat',
#     'lon',
#     'nic',
#     'rc',
#     'nac_p',
#     'nac_v',
#     'sil',
#     'sil_type'],
#    'messages': 6087897,
#    'seen': 0.7,
#    'rssi': -19.1},
#   {'hex': 'a581c8',
#    'type': 'tisb_icao',
#    'flight': 'N454JH  ',
#    'r': 'N454JH',
#    't': 'H500',
#    'dbFlags': 8,
#    'alt_baro': 2200,
#    'alt_geom': 2300,
#    'gs': 101.4,
#    'track': 282.53,
#    'baro_rate': -128,
#    'geom_rate': 64,
#    'squawk': '1200',
#    'emergency': 'none',
#    'category': 'A7',
#    'lat': 21.960205,
#    'lon': -159.517889,
#    'nic': 0,
#    'rc': 0,
#    'seen_pos': 0.375,
#    'version': 2,
#    'nic_baro': 0,
#    'nac_p': 0,
#    'nac_v': 0,
#    'sil': 0,
#    'sil_type': 'perhour',
#    'gva': 1,
#    'sda': 2,
#    'alert': 0,
#    'spi': 0,
#    'mlat': [],
#    'tisb': ['callsign',
#     'altitude',
#     'alt_geom',
#     'gs',
#     'track',
#     'baro_rate',
#     'lat',
#     'lon',
#     'nic',
#     'rc',
#     'nac_p',
#     'nac_v',
#     'sil',
#     'sil_type'],
#    'messages': 3326352,
#    'seen': 0.4,
#    'rssi': -18.9},
#   {'hex': '~284ede',
#    'type': 'tisb_trackfile',
#    'alt_baro': 2000,
#    'gs': 103.9,
#    'track': 258.91,
#    'geom_rate': 0,
#    'lat': 21.940292,
#    'lon': -159.457364,
#    'nic': 0,
#    'rc': 0,
#    'seen_pos': 8.889,
#    'nac_p': 0,
#    'nac_v': 0,
#    'sil': 0,
#    'sil_type': 'unknown',
#    'alert': 0,
#    'spi': 0,
#    'mlat': [],
#    'tisb': ['altitude',
#     'gs',
#     'track',
#     'geom_rate',
#     'lat',
#     'lon',
#     'nic',
#     'rc',
#     'nac_p',
#     'nac_v',
#     'sil',
#     'sil_type'],
#    'messages': 173,
#    'seen': 8.9,
#    'rssi': -19.3},
#   {'hex': 'a99e71',
#    'type': 'adsb_icao',
#    'flight': 'N719KV  ',
#    'r': 'N719KV',
#    't': 'H500',
#    'alt_baro': 1600,
#    'alt_geom': 1700,
#    'gs': 92.0,
#    'track': 268.75,
#    'baro_rate': 128,
#    'geom_rate': 128,
#    'squawk': '1200',
#    'emergency': 'none',
#    'category': 'A7',
#    'lat': 21.928299,
#    'lon': -159.399436,
#    'nic': 8,
#    'rc': 186,
#    'seen_pos': 0.716,
#    'version': 2,
#    'nic_baro': 1,
#    'nac_p': 9,
#    'nac_v': 2,
#    'sil': 3,
#    'sil_type': 'perhour',
#    'gva': 2,
#    'sda': 2,
#    'alert': 0,
#    'spi': 0,
#    'mlat': [],
#    'tisb': ['baro_rate'],
#    'messages': 5455101,
#    'seen': 0.4,
#    'rssi': -12.3},
#   {'hex': 'a9c505',
#    'type': 'tisb_icao',
#    'flight': 'N729AK  ',
#    'r': 'N729AK',
#    't': 'BE30',
#    'dbFlags': 8,
#    'alt_baro': 1525,
#    'alt_geom': 1625,
#    'gs': 143.1,
#    'track': 88.0,
#    'geom_rate': 0,
#    'category': 'A1',
#    'lat': 22.218979,
#    'lon': -159.376864,
#    'nic': 0,
#    'rc': 0,
#    'seen_pos': 0.716,
#    'nac_p': 0,
#    'nac_v': 0,
#    'sil': 0,
#    'sil_type': 'perhour',
#    'alert': 0,
#    'spi': 0,
#    'mlat': [],
#    'tisb': ['callsign',
#     'altitude',
#     'alt_geom',
#     'gs',
#     'track',
#     'geom_rate',
#     'lat',
#     'lon',
#     'nic',
#     'rc',
#     'nac_p',
#     'nac_v',
#     'sil',
#     'sil_type'],
#    'messages': 6747451,
#    'seen': 0.7,
#    'rssi': -18.8},
#   {'hex': 'aa1d85',
#    'type': 'adsr_icao',
#    'flight': 'N7508M  ',
#    'r': 'N7508M',
#    't': 'GA8',
#    'alt_baro': 300,
#    'alt_geom': 500,
#    'gs': 78.5,
#    'track': 44.48,
#    'baro_rate': -704,
#    'category': 'A1',
#    'lat': 21.96904,
#    'lon': -159.353044,
#    'nic': 0,
#    'rc': 0,
#    'seen_pos': 60.382,
#    'nac_v': 0,
#    'sil_type': 'perhour',
#    'alert': 0,
#    'spi': 0,
#    'mlat': [],
#    'tisb': [],
#    'messages': 2779440,
#    'seen': 60.4,
#    'rssi': -25.2},
#   {'hex': 'acd4f6',
#    'type': 'adsb_icao',
#    'flight': 'CPT7674 ',
#    'r': 'N926FE',
#    't': 'C208',
#    'alt_baro': 7050,
#    'alt_geom': 7400,
#    'gs': 161.1,
#    'track': 130.22,
#    'baro_rate': 0,
#    'squawk': '2253',
#    'emergency': 'none',
#    'category': 'A1',
#    'lat': 21.65712,
#    'lon': -158.69726,
#    'nic': 8,
#    'rc': 186,
#    'seen_pos': 0.258,
#    'version': 2,
#    'nic_baro': 1,
#    'nac_p': 9,
#    'nac_v': 2,
#    'sil': 3,
#    'sil_type': 'perhour',
#    'gva': 1,
#    'sda': 2,
#    'alert': 0,
#    'spi': 0,
#    'mlat': [],
#    'tisb': [],
#    'messages': 3197397,
#    'seen': 0.0,
#    'rssi': -24.9},
#   {'hex': '89901c',
#    'type': 'adsc',
#    'flight': 'CI8     ',
#    'r': 'B-18002',
#    't': 'B77W',
#    'alt_baro': 35000,
#    'gs': 570.0,
#    'track': 77.1,
#    'baro_rate': 16,
#    'lat': 35.296669,
#    'lon': -158.63245,
#    'nic': 0,
#    'rc': 0,
#    'seen_pos': 367.633,
#    'alert': 0,
#    'spi': 0,
#    'mlat': [],
#    'tisb': [],
#    'messages': 21567891,
#    'seen': 367.6,
#    'rssi': -49.5},
#   {'hex': '87304a',
#    'type': 'adsc',
#    'flight': 'NH101   ',
#    'r': 'JA928A',
#    't': 'B789',
#    'alt_baro': 29996,
#    'gs': 479.0,
#    'track': 225.55,
#    'baro_rate': -16,
#    'category': 'A5',
#    'lat': 57.765255,
#    'lon': -158.59211,
#    'nic': 0,
#    'rc': 0,
#    'seen_pos': 640.901,
#    'alert': 0,
#    'spi': 0,
#    'mlat': [],
#    'tisb': [],
#    'messages': 29905815,
#    'seen': 640.9,
#    'rssi': -49.5},
#   {'hex': 'ab00df',
#    'type': 'adsb_icao',
#    'flight': 'N808PE  ',
#    'r': 'N808PE',
#    't': 'C172',
#    'alt_baro': 4500,
#    'alt_geom': 4675,
#    'gs': 117.4,
#    'track': 135.69,
#    'baro_rate': -256,
#    'squawk': '1716',
#    'emergency': 'none',
#    'category': 'A1',
#    'nav_qnh': 1012.8,
#    'nav_altitude_mcp': 3008,
#    'lat': 21.28656,
#    'lon': -158.465698,
#    'nic': 8,
#    'rc': 186,
#    'seen_pos': 0.677,
#    'version': 2,
#    'nic_baro': 1,
#    'nac_p': 9,
#    'nac_v': 2,
#    'sil': 3,
#    'sil_type': 'perhour',
#    'gva': 1,
#    'sda': 2,
#    'alert': 0,
#    'spi': 0,
#    'mlat': [],
#    'tisb': [],
#    'messages': 15713219,
#    'seen': 0.0,
#    'rssi': -28.3},
#   {'hex': 'ac7e8a',
#    'type': 'adsb_icao',
#    'flight': 'CPT904  ',
#    'r': 'N904FE',
#    't': 'C208',
#    'alt_baro': 3575,
#    'alt_geom': 3775,
#    'gs': 156.1,
#    'track': 117.06,
#    'baro_rate': -640,
#    'geom_rate': -576,
#    'squawk': '2141',
#    'emergency': 'none',
#    'category': 'A1',
#    'lat': 21.407838,
#    'lon': -158.265279,
#    'nic': 8,
#    'rc': 186,
#    'seen_pos': 0.233,
#    'version': 2,
#    'nic_baro': 1,
#    'nac_p': 9,
#    'nac_v': 2,
#    'sil': 3,
#    'sil_type': 'perhour',
#    'gva': 1,
#    'sda': 2,
#    'alert': 0,
#    'spi': 0,
#    'mlat': [],
#    'tisb': ['geom_rate'],
#    'messages': 4846096,
#    'seen': 0.2,
#    'rssi': -28.4},
#   {'hex': 'a5fbdc',
#    'type': 'adsb_icao',
#    'flight': 'HAL293  ',
#    'r': 'N485HA',
#    't': 'B712',
#    'alt_baro': 8525,
#    'alt_geom': 8975,
#    'gs': 281.2,
#    'track': 277.15,
#    'baro_rate': 2112,
#    'geom_rate': 3072,
#    'squawk': '2154',
#    'emergency': 'none',
#    'category': 'A3',
#    'nav_qnh': 1012.8,
#    'nav_altitude_mcp': 14016,
#    'nav_heading': 265.78,
#    'lat': 21.259918,
#    'lon': -158.141652,
#    'nic': 8,
#    'rc': 186,
#    'seen_pos': 0.104,
#    'version': 2,
#    'nic_baro': 1,
#    'nac_p': 9,
#    'nac_v': 2,
#    'sil': 3,
#    'sil_type': 'perhour',
#    'gva': 2,
#    'sda': 2,
#    'alert': 0,
#    'spi': 0,
#    'mlat': [],
#    'tisb': ['geom_rate'],
#    'messages': 25661841,
#    'seen': 0.1,
#    'rssi': -16.7},
#   {'hex': 'a2bf8d',
#    'type': 'adsr_icao',
#    'flight': 'N2763F  ',
#    'r': 'N2763F',
#    't': 'C182',
#    'alt_baro': 1500,
#    'alt_geom': 1725,
#    'gs': 72.3,
#    'track': 221.63,
#    'geom_rate': -512,
#    'category': 'A1',
#    'lat': 21.419942,
#    'lon': -158.132324,
#    'nic': 0,
#    'rc': 0,
#    'seen_pos': 19.512,
#    'nic_baro': 0,
#    'nac_p': 9,
#    'nac_v': 0,
#    'sil': 3,
#    'sil_type': 'perhour',
#    'gva': 2,
#    'sda': 2,
#    'alert': 0,
#    'spi': 0,
#    'mlat': [],
#    'tisb': [],
#    'messages': 130716,
#    'seen': 19.5,
#    'rssi': -5.7},
#   {'hex': '~284eb7',
#    'type': 'tisb_trackfile',
#    'alt_baro': 1700,
#    'gs': 180.0,
#    'track': 287.13,
#    'geom_rate': 448,
#    'lat': 21.600586,
#    'lon': -158.128068,
#    'nic': 0,
#    'rc': 0,
#    'seen_pos': 9.803,
#    'nac_p': 0,
#    'nac_v': 0,
#    'sil': 0,
#    'sil_type': 'unknown',
#    'alert': 0,
#    'spi': 0,
#    'mlat': [],
#    'tisb': ['altitude',
#     'gs',
#     'track',
#     'geom_rate',
#     'lat',
#     'lon',
#     'nic',
#     'rc',
#     'nac_p',
#     'nac_v',
#     'sil',
#     'sil_type'],
#    'messages': 292,
#    'seen': 9.8,
#    'rssi': 0.0},
#   {'hex': 'a51d83',
#    'type': 'adsb_icao',
#    'flight': 'N429ES  ',
#    'r': 'N429ES',
#    't': 'C72R',
#    'alt_baro': 1225,
#    'alt_geom': 1250,
#    'gs': 92.7,
#    'track': 108.24,
#    'baro_rate': 128,
#    'geom_rate': 64,
#    'squawk': '1200',
#    'emergency': 'none',
#    'category': 'A1',
#    'nav_qnh': 1012.8,
#    'nav_heading': 136.41,
#    'lat': 21.346573,
#    'lon': -158.120728,
#    'nic': 8,
#    'rc': 186,
#    'seen_pos': 0.025,
#    'version': 2,
#    'nic_baro': 1,
#    'nac_p': 9,
#    'nac_v': 2,
#    'sil': 3,
#    'sil_type': 'perhour',
#    'gva': 1,
#    'sda': 2,
#    'alert': 0,
#    'spi': 0,
#    'mlat': [],
#    'tisb': ['geom_rate'],
#    'messages': 12741019,
#    'seen': 0.0,
#    'rssi': -8.9},
#   {'hex': '~284767',
#    'type': 'tisb_trackfile',
#    'alt_baro': 7800,
#    'gs': 77.8,
#    'track': 332.45,
#    'geom_rate': -256,
#    'lat': 21.527344,
#    'lon': -158.111439,
#    'nic': 0,
#    'rc': 0,
#    'seen_pos': 43.104,
#    'nac_p': 0,
#    'nac_v': 0,
#    'sil': 0,
#    'sil_type': 'unknown',
#    'alert': 0,
#    'spi': 0,
#    'mlat': [],
#    'tisb': ['altitude',
#     'gs',
#     'track',
#     'geom_rate',
#     'lat',
#     'lon',
#     'nic',
#     'rc',
#     'nac_p',
#     'nac_v',
#     'sil',
#     'sil_type'],
#    'messages': 2981,
#    'seen': 43.1,
#    'rssi': 0.0},
#   {'hex': 'a2a184',
#    'type': 'adsb_icao',
#    'flight': 'N269ME  ',
#    'r': 'N269ME',
#    't': 'C172',
#    'alt_baro': 1175,
#    'alt_geom': 1200,
#    'gs': 85.1,
#    'track': 19.93,
#    'baro_rate': 128,
#    'geom_rate': -128,
#    'squawk': '1200',
#    'emergency': 'none',
#    'category': 'A1',
#    'lat': 21.589904,
#    'lon': -158.079274,
#    'nic': 8,
#    'rc': 186,
#    'seen_pos': 0.478,
#    'version': 2,
#    'nic_baro': 1,
#    'nac_p': 9,
#    'nac_v': 2,
#    'sil': 3,
#    'sil_type': 'perhour',
#    'gva': 1,
#    'sda': 2,
#    'alert': 0,
#    'spi': 0,
#    'mlat': [],
#    'tisb': ['baro_rate'],
#    'messages': 21250905,
#    'seen': 0.0,
#    'rssi': -8.8},
#   {'hex': 'a6dca0',
#    'type': 'adsb_icao',
#    'flight': 'N541LC  ',
#    'r': 'N541LC',
#    't': 'C172',
#    'alt_baro': 750,
#    'alt_geom': 800,
#    'gs': 92.1,
#    'track': 57.86,
#    'baro_rate': 64,
#    'geom_rate': -64,
#    'squawk': '1200',
#    'emergency': 'none',
#    'category': 'A1',
#    'nav_qnh': 1012.8,
#    'nav_altitude_mcp': 800,
#    'nav_heading': 239.06,
#    'nav_modes': [],
#    'lat': 21.304958,
#    'lon': -158.048096,
#    'nic': 8,
#    'rc': 186,
#    'seen_pos': 0.025,
#    'version': 2,
#    'nic_baro': 1,
#    'nac_p': 9,
#    'nac_v': 2,
#    'sil': 3,
#    'sil_type': 'perhour',
#    'gva': 1,
#    'sda': 2,
#    'alert': 0,
#    'spi': 0,
#    'mlat': [],
#    'tisb': ['geom_rate'],
#    'messages': 13785664,
#    'seen': 0.0,
#    'rssi': -5.7},
#   {'hex': 'a9dc29',
#    'type': 'adsr_icao',
#    'flight': 'N734ZC  ',
#    'r': 'N734ZC',
#    't': 'C172',
#    'alt_baro': 500,
#    'alt_geom': 700,
#    'gs': 61.4,
#    'track': 199.03,
#    'geom_rate': -320,
#    'squawk': '1200',
#    'category': 'A1',
#    'lat': 21.339127,
#    'lon': -158.036041,
#    'nic': 7,
#    'rc': 371,
#    'seen_pos': 1.879,
#    'nic_baro': 0,
#    'nac_p': 9,
#    'nac_v': 1,
#    'sil': 3,
#    'sil_type': 'perhour',
#    'gva': 2,
#    'sda': 2,
#    'alert': 0,
#    'spi': 0,
#    'mlat': [],
#    'tisb': [],
#    'messages': 6680173,
#    'seen': 0.1,
#    'rssi': -13.8},
#   {'hex': '~284e44',
#    'type': 'tisb_other',
#    'alt_baro': 2100,
#    'alt_geom': 1325,
#    'gs': 237.5,
#    'track': 310.73,
#    'geom_rate': 64,
#    'lat': 21.050643,
#    'lon': -157.98645,
#    'nic': 6,
#    'rc': 926,
#    'seen_pos': 11.717,
#    'nac_p': 6,
#    'nac_v': 0,
#    'sil': 2,
#    'sil_type': 'unknown',
#    'alert': 0,
#    'spi': 0,
#    'mlat': [],
#    'tisb': ['altitude',
#     'alt_geom',
#     'gs',
#     'track',
#     'geom_rate',
#     'lat',
#     'lon',
#     'nic',
#     'rc',
#     'nac_p',
#     'nac_v',
#     'sil',
#     'sil_type'],
#    'messages': 125,
#    'seen': 11.7,
#    'rssi': -3.4},
#   {'hex': 'a716d0',
#    'type': 'adsb_icao',
#    'flight': 'N556MH  ',
#    'r': 'N556MH',
#    't': 'H500',
#    'alt_baro': 875,
#    'alt_geom': 975,
#    'gs': 104.3,
#    'track': 282.17,
#    'baro_rate': 320,
#    'geom_rate': 320,
#    'squawk': '1200',
#    'emergency': 'none',
#    'category': 'A7',
#    'lat': 21.376695,
#    'lon': -157.982788,
#    'nic': 9,
#    'rc': 75,
#    'seen_pos': 0.233,
#    'version': 2,
#    'nic_baro': 1,
#    'nac_p': 10,
#    'nac_v': 1,
#    'sil': 3,
#    'sil_type': 'perhour',
#    'gva': 2,
#    'sda': 2,
#    'alert': 1,
#    'spi': 0,
#    'mlat': [],
#    'tisb': ['baro_rate'],
#    'messages': 10065858,
#    'seen': 0.2,
#    'rssi': -8.1},
#   {'hex': '~300f5d',
#    'type': 'tisb_trackfile',
#    'alt_baro': 2400,
#    'alt_geom': 2350,
#    'gs': 227.7,
#    'track': 188.84,
#    'baro_rate': 1728,
#    'geom_rate': 2176,
#    'lat': 21.291412,
#    'lon': -157.976857,
#    'nic': 0,
#    'rc': 0,
#    'seen_pos': 2.096,
#    'nac_p': 0,
#    'nac_v': 0,
#    'sil': 0,
#    'sil_type': 'unknown',
#    'alert': 0,
#    'spi': 0,
#    'mlat': [],
#    'tisb': ['altitude',
#     'alt_geom',
#     'gs',
#     'track',
#     'baro_rate',
#     'geom_rate',
#     'lat',
#     'lon',
#     'nic',
#     'rc',
#     'nac_p',
#     'nac_v',
#     'sil',
#     'sil_type'],
#    'messages': 343,
#    'seen': 2.1,
#    'rssi': 0.0},
#   {'hex': 'a5d45d',
#    'type': 'adsb_icao',
#    'flight': 'HAL318  ',
#    'r': 'N475HA',
#    't': 'B712',
#    'alt_baro': 2500,
#    'alt_geom': 2650,
#    'gs': 231.0,
#    'track': 180.5,
#    'baro_rate': 2240,
#    'geom_rate': 2176,
#    'squawk': '2171',
#    'emergency': 'none',
#    'category': 'A3',
#    'nav_qnh': 1012.8,
#    'nav_altitude_mcp': 12992,
#    'nav_heading': 147.66,
#    'lat': 21.289124,
#    'lon': -157.976757,
#    'nic': 8,
#    'rc': 186,
#    'seen_pos': 0.025,
#    'version': 2,
#    'nic_baro': 1,
#    'nac_p': 9,
#    'nac_v': 2,
#    'sil': 3,
#    'sil_type': 'perhour',
#    'gva': 2,
#    'sda': 2,
#    'alert': 0,
#    'spi': 0,
#    'mlat': [],
#    'tisb': ['geom_rate'],
#    'messages': 24549526,
#    'seen': 0.0,
#    'rssi': -5.9},
#   {'hex': '~284eee',
#    'type': 'tisb_other',
#    'alt_baro': 1400,
#    'alt_geom': 2175,
#    'gs': 67.3,
#    'track': 95.12,
#    'geom_rate': 256,
#    'lat': 21.473663,
#    'lon': -157.972666,
#    'nic': 6,
#    'rc': 926,
#    'seen_pos': 14.447,
#    'nac_p': 6,
#    'nac_v': 0,
#    'sil': 2,
#    'sil_type': 'unknown',
#    'alert': 0,
#    'spi': 0,
#    'mlat': [],
#    'tisb': ['altitude',
#     'alt_geom',
#     'gs',
#     'track',
#     'geom_rate',
#     'lat',
#     'lon',
#     'nic',
#     'rc',
#     'nac_p',
#     'nac_v',
#     'sil',
#     'sil_type'],
#    'messages': 21,
#    'seen': 14.4,
#    'rssi': -4.9},
#   {'hex': 'a323be',
#    'type': 'adsb_icao',
#    'flight': 'N301HF  ',
#    'r': 'N301HF',
#    't': 'H500',
#    'alt_baro': 1600,
#    'alt_geom': 1525,
#    'gs': 72.0,
#    'track': 90.0,
#    'baro_rate': 0,
#    'geom_rate': 0,
#    'squawk': '1200',
#    'emergency': 'none',
#    'category': 'A7',
#    'lat': 21.473785,
#    'lon': -157.967868,
#    'nic': 8,
#    'rc': 186,
#    'seen_pos': 1.611,
#    'version': 2,
#    'nic_baro': 0,
#    'nac_p': 9,
#    'nac_v': 2,
#    'sil': 3,
#    'sil_type': 'perhour',
#    'gva': 1,
#    'sda': 2,
#    'alert': 0,
#    'spi': 0,
#    'mlat': [],
#    'tisb': ['baro_rate'],
#    'messages': 2308379,
#    'seen': 1.2,
#    'rssi': -9.0},
#   {'hex': 'ae568a',
#    'type': 'adsb_icao',
#    'flight': 'SURF60  ',
#    'r': '13-20546',
#    't': 'H60',
#    'dbFlags': 1,
#    'alt_baro': 1325,
#    'alt_geom': 1425,
#    'gs': 50.0,
#    'track': 160.11,
#    'baro_rate': -576,
#    'geom_rate': -512,
#    'squawk': '1200',
#    'emergency': 'none',
#    'category': 'A7',
#    'nav_qnh': 1012.8,
#    'nav_heading': 37.27,
#    'nav_modes': [],
#    'lat': 21.487815,
#    'lon': -157.963664,
#    'nic': 8,
#    'rc': 186,
#    'seen_pos': 0.992,
#    'version': 2,
#    'nic_baro': 1,
#    'nac_p': 11,
#    'nac_v': 4,
#    'sil': 3,
#    'sil_type': 'perhour',
#    'gva': 2,
#    'sda': 2,
#    'alert': 0,
#    'spi': 0,
#    'mlat': [],
#    'tisb': ['geom_rate'],
#    'messages': 246638,
#    'seen': 0.7,
#    'rssi': -22.9},
#   {'hex': 'ae59fe',
#    'type': 'adsb_icao',
#    'flight': 'CARGO10 ',
#    'r': '16-08205',
#    't': 'H47',
#    'dbFlags': 1,
#    'alt_baro': 1900,
#    'alt_geom': 1975,
#    'gs': 65.1,
#    'track': 316.25,
#    'baro_rate': 0,
#    'geom_rate': 64,
#    'squawk': '1200',
#    'emergency': 'none',
#    'category': 'A7',
#    'lat': 21.510393,
#    'lon': -157.963613,
#    'nic': 7,
#    'rc': 371,
#    'seen_pos': 0.311,
#    'version': 2,
#    'nic_baro': 1,
#    'nac_p': 9,
#    'nac_v': 4,
#    'sil': 3,
#    'sil_type': 'perhour',
#    'gva': 2,
#    'sda': 2,
#    'alert': 0,
#    'spi': 0,
#    'mlat': [],
#    'tisb': [],
#    'messages': 343104,
#    'seen': 0.1,
#    'rssi': -16.4},
#   {'hex': 'a32775',
#    'type': 'adsb_icao',
#    'flight': 'N302HF  ',
#    'r': 'N302HF',
#    't': 'H500',
#    'alt_baro': 1350,
#    'alt_geom': 1425,
#    'gs': 66.7,
#    'track': 282.99,
#    'baro_rate': 576,
#    'geom_rate': 448,
#    'squawk': '1200',
#    'emergency': 'none',
#    'category': 'A7',
#    'lat': 21.479599,
#    'lon': -157.962375,
#    'nic': 8,
#    'rc': 186,
#    'seen_pos': 0.675,
#    'version': 2,
#    'nic_baro': 1,
#    'nac_p': 9,
#    'nac_v': 2,
#    'sil': 3,
#    'sil_type': 'perhour',
#    'gva': 2,
#    'sda': 2,
#    'alert': 0,
#    'spi': 0,
#    'mlat': [],
#    'tisb': ['baro_rate'],
#    'messages': 1898975,
#    'seen': 0.7,
#    'rssi': -25.1},
#   {'hex': 'aa0a53',
#    'type': 'tisb_icao',
#    'flight': 'N746RH  ',
#    'r': 'N746RH',
#    't': 'AS50',
#    'alt_baro': 2000,
#    'alt_geom': 1950,
#    'gs': 109.8,
#    'track': 138.32,
#    'baro_rate': -320,
#    'category': 'A7',
#    'lat': 21.624985,
#    'lon': -157.951488,
#    'nic': 0,
#    'rc': 0,
#    'seen_pos': 47.645,
#    'version': 2,
#    'nac_p': 0,
#    'nac_v': 0,
#    'sil': 0,
#    'sil_type': 'perhour',
#    'alert': 0,
#    'spi': 0,
#    'mlat': [],
#    'tisb': ['callsign',
#     'altitude',
#     'alt_geom',
#     'gs',
#     'track',
#     'baro_rate',
#     'lat',
#     'lon',
#     'nic',
#     'rc',
#     'nac_p',
#     'nac_v',
#     'sil',
#     'sil_type'],
#    'messages': 17023264,
#    'seen': 47.6,
#    'rssi': 0.0},
#   {'hex': '~284e5e',
#    'type': 'tisb_trackfile',
#    'alt_baro': 500,
#    'gs': 79.8,
#    'track': 127.87,
#    'geom_rate': 0,
#    'lat': 21.705734,
#    'lon': -157.946694,
#    'nic': 0,
#    'rc': 0,
#    'seen_pos': 43.385,
#    'nac_p': 0,
#    'nac_v': 0,
#    'sil': 0,
#    'sil_type': 'unknown',
#    'alert': 0,
#    'spi': 0,
#    'mlat': [],
#    'tisb': ['altitude',
#     'gs',
#     'track',
#     'geom_rate',
#     'lat',
#     'lon',
#     'nic',
#     'rc',
#     'nac_p',
#     'nac_v',
#     'sil',
#     'sil_type'],
#    'messages': 564,
#    'seen': 42.0,
#    'rssi': -0.0},
#   {'hex': '~3005b6',
#    'type': 'tisb_trackfile',
#    'alt_baro': 'ground',
#    'gs': 1.9,
#    'lat': 21.328537,
#    'lon': -157.945208,
#    'nic': 0,
#    'rc': 186,
#    'seen_pos': 38.246,
#    'nac_p': 0,
#    'nac_v': 1,
#    'sil': 2,
#    'sil_type': 'unknown',
#    'mlat': [],
#    'tisb': ['gs',
#     'lat',
#     'lon',
#     'nic',
#     'rc',
#     'nac_p',
#     'nac_v',
#     'sil',
#     'sil_type'],
#    'messages': 636,
#    'seen': 38.2,
#    'rssi': -2.9},
#   {'hex': 'a45bfa',
#    'type': 'adsb_icao',
#    'flight': 'HAL22   ',
#    'r': 'N380HA',
#    't': 'A332',
#    'alt_baro': 625,
#    'alt_geom': 700,
#    'gs': 169.1,
#    'track': 267.63,
#    'true_heading': 270.0,
#    'baro_rate': 2496,
#    'geom_rate': 2368,
#    'squawk': '2666',
#    'emergency': 'none',
#    'category': 'A5',
#    'nav_qnh': 1012.8,
#    'nav_altitude_mcp': 4992,
#    'nav_heading': 199.69,
#    'lat': 21.325378,
#    'lon': -157.944547,
#    'nic': 8,
#    'rc': 186,
#    'seen_pos': 0.233,
#    'version': 2,
#    'nic_baro': 1,
#    'nac_p': 8,
#    'nac_v': 1,
#    'sil': 3,
#    'sil_type': 'perhour',
#    'gva': 1,
#    'sda': 2,
#    'alert': 0,
#    'spi': 0,
#    'mlat': [],
#    'tisb': ['geom_rate'],
#    'messages': 21730691,
#    'seen': 0.2,
#    'rssi': -6.9},
#   {'hex': '~300de6',
#    'type': 'tisb_other',
#    'alt_baro': 'ground',
#    'gs': 0.0,
#    'track': 0.0,
#    'lat': 21.32629,
#    'lon': -157.944361,
#    'nic': 8,
#    'rc': 186,
#    'seen_pos': 1.23,
#    'nac_p': 8,
#    'nac_v': 1,
#    'sil': 2,
#    'sil_type': 'unknown',
#    'mlat': [],
#    'tisb': ['gs',
#     'track',
#     'lat',
#     'lon',
#     'nic',
#     'rc',
#     'nac_p',
#     'nac_v',
#     'sil',
#     'sil_type'],
#    'messages': 15041,
#    'seen': 0.2,
#    'rssi': -6.0},
#   {'hex': '~3001e2',
#    'type': 'tisb_other',
#    'alt_baro': 'ground',
#    'gs': 1.9,
#    'track': 0.0,
#    'lat': 21.323009,
#    'lon': -157.944322,
#    'nic': 8,
#    'rc': 186,
#    'seen_pos': 4.344,
#    'nac_p': 8,
#    'nac_v': 1,
#    'sil': 2,
#    'sil_type': 'unknown',
#    'mlat': [],
#    'tisb': ['gs',
#     'track',
#     'lat',
#     'lon',
#     'nic',
#     'rc',
#     'nac_p',
#     'nac_v',
#     'sil',
#     'sil_type'],
#    'messages': 547,
#    'seen': 4.3,
#    'rssi': -6.7},
#   {'hex': '~300280',
#    'type': 'tisb_other',
#    'alt_baro': 'ground',
#    'gs': 3.8,
#    'track': 230.62,
#    'lat': 21.323043,
#    'lon': -157.94426,
#    'nic': 8,
#    'rc': 186,
#    'seen_pos': 31.208,
#    'nac_p': 8,
#    'nac_v': 1,
#    'sil': 2,
#    'sil_type': 'unknown',
#    'mlat': [],
#    'tisb': ['gs',
#     'track',
#     'lat',
#     'lon',
#     'nic',
#     'rc',
#     'nac_p',
#     'nac_v',
#     'sil',
#     'sil_type'],
#    'messages': 450,
#    'seen': 31.2,
#    'rssi': -6.1},
#   {'hex': '~300537',
#    'type': 'tisb_other',
#    'alt_baro': 'ground',
#    'gs': 27.5,
#    'track': 222.19,
#    'lat': 21.323113,
#    'lon': -157.944196,
#    'nic': 8,
#    'rc': 186,
#    'seen_pos': 1.23,
#    'nac_p': 8,
#    'nac_v': 1,
#    'sil': 2,
#    'sil_type': 'unknown',
#    'mlat': [],
#    'tisb': ['gs',
#     'track',
#     'lat',
#     'lon',
#     'nic',
#     'rc',
#     'nac_p',
#     'nac_v',
#     'sil',
#     'sil_type'],
#    'messages': 119,
#    'seen': 1.2,
#    'rssi': -5.9},
#   {'hex': '~30088e',
#    'type': 'tisb_other',
#    'alt_baro': 'ground',
#    'gs': 31.9,
#    'track': 212.2,
#    'lat': 21.323241,
#    'lon': -157.944069,
#    'nic': 8,
#    'rc': 186,
#    'seen_pos': 24.556,
#    'nac_p': 8,
#    'nac_v': 1,
#    'sil': 2,
#    'sil_type': 'unknown',
#    'mlat': [],
#    'tisb': ['gs',
#     'track',
#     'lat',
#     'lon',
#     'nic',
#     'rc',
#     'nac_p',
#     'nac_v',
#     'sil',
#     'sil_type'],
#    'messages': 857,
#    'seen': 24.6,
#    'rssi': -11.7},
#   {'hex': '~300306',
#    'type': 'tisb_other',
#    'alt_baro': 'ground',
#    'gs': 0.0,
#    'track': 0.0,
#    'lat': 21.327081,
#    'lon': -157.943789,
#    'nic': 10,
#    'rc': 25,
#    'seen_pos': 0.233,
#    'nac_p': 10,
#    'nac_v': 2,
#    'sil': 2,
#    'sil_type': 'unknown',
#    'mlat': [],
#    'tisb': ['gs',
#     'track',
#     'lat',
#     'lon',
#     'nic',
#     'rc',
#     'nac_p',
#     'nac_v',
#     'sil',
#     'sil_type'],
#    'messages': 1916,
#    'seen': 0.2,
#    'rssi': -4.6},
#   {'hex': 'a5dbcb',
#    'type': 'adsb_icao',
#    'flight': 'HAL264  ',
#    'r': 'N477HA',
#    't': 'B712',
#    'alt_baro': 'ground',
#    'gs': 13.2,
#    'true_heading': 28.12,
#    'squawk': '2153',
#    'emergency': 'none',
#    'category': 'A3',
#    'lat': 21.323891,
#    'lon': -157.942724,
#    'nic': 8,
#    'rc': 186,
#    'seen_pos': 3.95,
#    'version': 2,
#    'nac_p': 9,
#    'nac_v': 2,
#    'sil': 3,
#    'sil_type': 'perhour',
#    'sda': 2,
#    'alert': 0,
#    'spi': 0,
#    'mlat': [],
#    'tisb': [],
#    'messages': 21237023,
#    'seen': 4.0,
#    'rssi': -15.5},
#   {'hex': '~30023f',
#    'type': 'tisb_trackfile',
#    'alt_baro': 'ground',
#    'gs': 0.0,
#    'lat': 21.323158,
#    'lon': -157.942699,
#    'nic': 0,
#    'rc': 0,
#    'seen_pos': 58.296,
#    'nac_p': 0,
#    'nac_v': 1,
#    'sil': 2,
#    'sil_type': 'unknown',
#    'mlat': [],
#    'tisb': ['gs',
#     'lat',
#     'lon',
#     'nic',
#     'rc',
#     'nac_p',
#     'nac_v',
#     'sil',
#     'sil_type'],
#    'messages': 224,
#    'seen': 58.3,
#    'rssi': -2.7},
#   {'hex': 'a46ad6',
#    'type': 'adsb_icao',
#    'flight': 'HAL7    ',
#    'r': 'N384HA',
#    't': 'A332',
#    'alt_baro': 'ground',
#    'alt_geom': 125,
#    'gs': 23.5,
#    'true_heading': 292.5,
#    'squawk': '2152',
#    'emergency': 'none',
#    'category': 'A5',
#    'lat': 21.309677,
#    'lon': -157.939628,
#    'nic': 8,
#    'rc': 186,
#    'seen_pos': 0.233,
#    'version': 2,
#    'nac_p': 8,
#    'nac_v': 1,
#    'sil': 3,
#    'sil_type': 'perhour',
#    'sda': 2,
#    'alert': 0,
#    'spi': 0,
#    'mlat': [],
#    'tisb': [],
#    'messages': 25285349,
#    'seen': 0.2,
#    'rssi': -16.6},
#   {'hex': 'a5ff93',
#    'type': 'adsb_icao',
#    'flight': 'HAL306  ',
#    'r': 'N486HA',
#    't': 'B712',
#    'alt_baro': 4075,
#    'alt_geom': 4275,
#    'gs': 252.4,
#    'track': 134.84,
#    'baro_rate': 1792,
#    'geom_rate': 1792,
#    'squawk': '2205',
#    'emergency': 'none',
#    'category': 'A3',
#    'nav_qnh': 1012.8,
#    'nav_altitude_mcp': 12992,
#    'nav_heading': 120.23,
#    'lat': 21.230567,
#    'lon': -157.939148,
#    'nic': 8,
#    'rc': 186,
#    'seen_pos': 0.025,
#    'version': 2,
#    'nic_baro': 1,
#    'nac_p': 9,
#    'nac_v': 2,
#    'sil': 3,
#    'sil_type': 'perhour',
#    'gva': 2,
#    'sda': 2,
#    'alert': 0,
#    'spi': 0,
#    'mlat': [],
#    'tisb': ['geom_rate'],
#    'messages': 25972447,
#    'seen': 0.0,
#    'rssi': -5.7},
#   {'hex': '~30040f',
#    'type': 'tisb_trackfile',
#    'alt_baro': 300,
#    'gs': 173.0,
#    'track': 271.32,
#    'geom_rate': 2944,
#    'lat': 21.325378,
#    'lon': -157.938704,
#    'nic': 0,
#    'rc': 0,
#    'seen_pos': 6.865,
#    'nac_p': 0,
#    'nac_v': 0,
#    'sil': 0,
#    'sil_type': 'unknown',
#    'alert': 0,
#    'spi': 0,
#    'mlat': [],
#    'tisb': ['altitude',
#     'gs',
#     'track',
#     'geom_rate',
#     'lat',
#     'lon',
#     'nic',
#     'rc',
#     'nac_p',
#     'nac_v',
#     'sil',
#     'sil_type'],
#    'messages': 180,
#    'seen': 6.9,
#    'rssi': -0.0},
#   {'hex': '~3001c9',
#    'type': 'tisb_other',
#    'alt_baro': 'ground',
#    'gs': 4.1,
#    'track': 90.0,
#    'lat': 21.309892,
#    'lon': -157.938385,
#    'nic': 8,
#    'rc': 186,
#    'seen_pos': 13.349,
#    'nac_p': 8,
#    'nac_v': 1,
#    'sil': 2,
#    'sil_type': 'unknown',
#    'mlat': [],
#    'tisb': ['gs',
#     'track',
#     'lat',
#     'lon',
#     'nic',
#     'rc',
#     'nac_p',
#     'nac_v',
#     'sil',
#     'sil_type'],
#    'messages': 230,
#    'seen': 13.3,
#    'rssi': -11.8},
#   {'hex': 'a610c8',
#    'type': 'adsb_icao',
#    'flight': 'HAL265  ',
#    'r': 'N490HA',
#    't': 'B712',
#    'alt_baro': 'ground',
#    'gs': 10.2,
#    'track': 0.0,
#    'true_heading': 0.0,
#    'baro_rate': 0,
#    'squawk': '2166',
#    'emergency': 'none',
#    'category': 'A3',
#    'lat': 21.324626,
#    'lon': -157.927272,
#    'nic': 8,
#    'rc': 186,
#    'seen_pos': 0.233,
#    'version': 2,
#    'nac_p': 9,
#    'nac_v': 2,
#    'sil': 3,
#    'sil_type': 'perhour',
#    'sda': 2,
#    'alert': 0,
#    'spi': 0,
#    'mlat': [],
#    'tisb': [],
#    'messages': 23402183,
#    'seen': 0.2,
#    'rssi': -12.3},
#   {'hex': '~3003f6',
#    'type': 'tisb_trackfile',
#    'alt_baro': 'ground',
#    'gs': 16.5,
#    'track': 90.0,
#    'lat': 21.326912,
#    'lon': -157.926682,
#    'nic': 0,
#    'rc': 186,
#    'seen_pos': 5.287,
#    'nac_p': 0,
#    'nac_v': 0,
#    'sil': 2,
#    'sil_type': 'unknown',
#    'mlat': [],
#    'tisb': ['gs',
#     'track',
#     'lat',
#     'lon',
#     'nic',
#     'rc',
#     'nac_p',
#     'nac_v',
#     'sil',
#     'sil_type'],
#    'messages': 53,
#    'seen': 5.3,
#    'rssi': -4.6},
#   {'hex': 'a4960c',
#    'type': 'adsb_icao',
#    'flight': 'HAL827  ',
#    'r': 'N395HA',
#    't': 'A332',
#    'alt_baro': 'ground',
#    'gs': 17.5,
#    'true_heading': 90.0,
#    'squawk': '2667',
#    'emergency': 'none',
#    'category': 'A5',
#    'lat': 21.327003,
#    'lon': -157.926195,
#    'nic': 8,
#    'rc': 186,
#    'seen_pos': 0.025,
#    'version': 2,
#    'nac_p': 8,
#    'nac_v': 1,
#    'sil': 3,
#    'sil_type': 'perhour',
#    'sda': 2,
#    'alert': 0,
#    'spi': 0,
#    'mlat': [],
#    'tisb': [],
#    'messages': 19690953,
#    'seen': 0.0,
#    'rssi': -11.2},
#   {'hex': 'a6147f',
#    'type': 'other',
#    'flight': 'HAL251  ',
#    'r': 'N491HA',
#    't': 'B712',
#    'alt_baro': 'ground',
#    'gs': 5.8,
# ...
#    'oat': -59,
#    'tat': -34,
#    'track': 271.52,
#    'track_rate': -0.03,
#    'roll': -0.53,
#    'mag_heading': 256.29,
#    'true_heading': 268.69,
#    'baro_rate': 0,
#    'geom_rate': 0,
#    'squawk': '3354',
#    'emergency': 'none',
#    'category': 'A3',
#    'nav_qnh': 1013.6,
#    'nav_altitude_mcp': 36000,
#    'nav_heading': 0.0,
#    'lat': 37.680033,
#    'lon': -119.127861,
#    'nic': 8,
#    'rc': 186,
#    'seen_pos': 0.145,
#    'version': 2,
#    'nic_baro': 1,
#    'nac_p': 10,
#    'nac_v': 2,
#    'sil': 3,
#    'sil_type': 'perhour',
#    'gva': 2,
#    'sda': 2,
#    'alert': 0,
#    'spi': 0,
#    'mlat': [],
#    'tisb': [],
#    'messages': 69218055,
#    'seen': 0.1,
#    'rssi': -13.9},
#   {'hex': 'a851ed',
#    'type': 'adsb_icao',
#    'flight': 'CXK635  ',
#    'r': 'N635SP',
#    't': 'C172',
#    'dbFlags': 8,
#    'alt_baro': 4900,
#    'alt_geom': 5125,
#    'gs': 95.4,
#    'track': 95.41,
#    'geom_rate': -64,
#    'squawk': '4607',
#    'emergency': 'none',
#    'category': 'A1',
#    'lat': 34.245735,
#    'lon': -119.124355,
#    'nic': 10,
#    'rc': 25,
#    'seen_pos': 0.537,
#    'version': 2,
#    'nic_baro': 0,
#    'nac_p': 10,
#    'nac_v': 2,
#    'sil': 3,
#    'sil_type': 'perhour',
#    'gva': 2,
#    'sda': 2,
#    'alert': 0,
#    'spi': 0,
#    'mlat': [],
#    'tisb': [],
#    'messages': 5694391,
#    'seen': 0.0,
#    'rssi': -5.8},
#   {'hex': 'c031c9',
#    'type': 'adsb_icao',
#    'flight': 'WEN3125 ',
#    'r': 'C-FSWE',
#    't': 'DH8D',
#    'alt_baro': 13000,
#    'alt_geom': 13275,
#    'gs': 293.4,
#    'track': 216.13,
#    'baro_rate': -1600,
#    'squawk': '1346',
#    'emergency': 'none',
#    'category': 'A2',
#    'nav_qnh': 1024.0,
#    'nav_altitude_mcp': 8992,
#    'nav_heading': 206.02,
#    'lat': 50.520172,
#    'lon': -119.117456,
#    'nic': 8,
#    'rc': 186,
#    'seen_pos': 0.362,
#    'version': 2,
#    'nic_baro': 1,
#    'nac_p': 10,
#    'nac_v': 1,
#    'sil': 3,
#    'sil_type': 'perhour',
#    'gva': 2,
#    'sda': 2,
#    'alert': 0,
#    'spi': 0,
#    'mlat': [],
#    'tisb': [],
#    'messages': 24085574,
#    'seen': 0.4,
#    'rssi': -19.1},
#   {'hex': 'ac4ba3',
#    'type': 'adsb_icao',
#    'flight': 'N89114  ',
#    'r': 'N89114',
#    't': 'C152',
#    'alt_baro': 2000,
#    'alt_geom': 1925,
#    'gs': 95.5,
#    'track': 30.86,
#    'geom_rate': 0,
#    'squawk': '0277',
#    'emergency': 'none',
#    'category': 'A1',
#    'lat': 35.344162,
#    'lon': -119.112167,
#    'nic': 8,
#    'rc': 186,
#    'seen_pos': 0.911,
#    'version': 2,
#    'nic_baro': 0,
#    'nac_p': 10,
#    'nac_v': 2,
#    'sil': 3,
#    'sil_type': 'perhour',
#    'gva': 2,
#    'sda': 2,
#    'alert': 0,
#    'spi': 0,
#    'mlat': [],
#    'tisb': [],
#    'messages': 8811749,
#    'seen': 0.2,
#    'rssi': -1.9},
#   {'hex': 'a55055',
#    'type': 'adsb_icao',
#    'flight': 'SWA2538 ',
#    'r': 'N441WN',
#    't': 'B737',
#    'alt_baro': 39000,
#    'alt_geom': 40150,
#    'gs': 451.5,
#    'ias': 245,
#    'tas': 448,
#    'mach': 0.792,
#    'wd': 245,
#    'ws': 9,
#    'oat': -62,
#    'tat': -36,
#    'track': 131.14,
#    'track_rate': 0.0,
#    'roll': 0.35,
#    'mag_heading': 120.23,
#    'true_heading': 132.14,
#    'baro_rate': -64,
#    'geom_rate': 32,
#    'squawk': '3212',
#    'emergency': 'none',
#    'category': 'A3',
#    'lat': 35.212463,
#    'lon': -119.106763,
#    'nic': 8,
#    'rc': 186,
#    'seen_pos': 0.0,
#    'version': 2,
#    'nic_baro': 1,
#    'nac_p': 10,
#    'nac_v': 2,
#    'sil': 3,
#    'sil_type': 'perhour',
#    'gva': 2,
#    'sda': 2,
#    'alert': 0,
#    'spi': 0,
#    'mlat': [],
#    'tisb': [],
#    'messages': 43458660,
#    'seen': 0.0,
#    'rssi': -13.3},
#   {'hex': 'a9ed8f',
#    'type': 'adsr_icao',
#    'flight': 'N739MB  ',
#    'r': 'N739MB',
#    't': 'C172',
#    'dbFlags': 8,
#    'alt_baro': 3200,
#    'alt_geom': 3325,
#    'gs': 98.4,
#    'track': 132.12,
#    'baro_rate': 1152,
#    'squawk': '1200',
#    'emergency': 'none',
#    'category': 'A1',
#    'lat': 34.337082,
#    'lon': -119.107323,
#    'nic': 0,
#    'rc': 0,
#    'seen_pos': 0.478,
#    'nac_v': 0,
#    'sil_type': 'perhour',
#    'alert': 0,
#    'spi': 0,
#    'mlat': [],
#    'tisb': [],
#    'messages': 4052521,
#    'seen': 0.5,
#    'rssi': 0.0},
#   {'hex': 'a3db3e',
#    'type': 'adsb_icao',
#    'flight': 'N348CF  ',
#    'r': 'N348CF',
#    't': 'C750',
#    'alt_baro': 11825,
#    'alt_geom': 12325,
#    'gs': 342.8,
#    'ias': 285,
#    'tas': 346,
#    'mach': 0.532,
#    'wd': 264,
#    'ws': 9,
#    'oat': 5,
#    'tat': 21,
#    'track': 338.97,
#    'track_rate': 0.0,
#    'roll': 0.35,
#    'mag_heading': 325.2,
#    'true_heading': 337.29,
#    'baro_rate': -1920,
#    'geom_rate': -1856,
#    'squawk': '7263',
#    'emergency': 'none',
#    'category': 'A2',
#    'nav_qnh': 1018.4,
#    'nav_altitude_mcp': 11008,
#    'lat': 36.091019,
#    'lon': -119.105121,
#    'nic': 8,
#    'rc': 186,
#    'seen_pos': 0.025,
#    'version': 2,
#    'nic_baro': 1,
#    'nac_p': 10,
#    'nac_v': 2,
#    'sil': 3,
#    'sil_type': 'perhour',
#    'gva': 2,
#    'sda': 2,
#    'alert': 0,
#    'spi': 0,
#    'mlat': [],
#    'tisb': [],
#    'messages': 16131679,
#    'seen': 0.0,
#    'rssi': -6.7},
#   {'hex': '~2b8cf0',
#    'type': 'tisb_other',
#    'alt_baro': 1700,
#    'alt_geom': 925,
#    'gs': 92.8,
#    'track': 281.19,
#    'geom_rate': 0,
#    'lat': 47.006516,
#    'lon': -119.103607,
#    'nic': 6,
#    'rc': 926,
#    'seen_pos': 19.214,
#    'nac_p': 6,
#    'nac_v': 0,
#    'sil': 2,
#    'sil_type': 'unknown',
#    'alert': 0,
#    'spi': 0,
#    'mlat': [],
#    'tisb': ['altitude',
#     'alt_geom',
#     'gs',
#     'track',
#     'geom_rate',
#     'lat',
#     'lon',
#     'nic',
#     'rc',
#     'nac_p',
#     'nac_v',
#     'sil',
#     'sil_type'],
#    'messages': 43,
#    'seen': 19.2,
#    'rssi': -9.9},
#   {'hex': 'a5ad74',
#    'type': 'adsb_icao',
#    'flight': 'N465PA  ',
#    'r': 'N465PA',
#    't': 'E120',
#    'alt_baro': 2400,
#    'alt_geom': 2450,
#    'gs': 187.3,
#    'track': 229.76,
#    'geom_rate': -448,
#    'squawk': '4653',
#    'emergency': 'none',
#    'category': 'A2',
#    'lat': 34.186101,
#    'lon': -119.098492,
#    'nic': 9,
#    'rc': 75,
#    'seen_pos': 0.478,
#    'version': 2,
#    'nic_baro': 0,
#    'nac_p': 10,
#    'nac_v': 2,
#    'sil': 3,
#    'sil_type': 'perhour',
#    'gva': 2,
#    'sda': 2,
#    'alert': 0,
#    'spi': 0,
#    'mlat': [],
#    'tisb': [],
#    'messages': 7757591,
#    'seen': 0.1,
#    'rssi': -8.3},
#   {'hex': 'c069d8',
#    'type': 'adsb_icao',
#    'flight': 'WJA1514 ',
#    'r': 'C-GOCD',
#    't': 'B738',
#    'alt_baro': 19025,
#    'alt_geom': 19800,
#    'gs': 379.8,
#    'ias': 281,
#    'tas': 378,
#    'mach': 0.6,
#    'wd': 292,
#    'ws': 3,
#    'oat': -12,
#    'tat': 7,
#    'track': 143.67,
#    'track_rate': 0.03,
#    'roll': -0.35,
#    'mag_heading': 132.01,
#    'true_heading': 143.78,
#    'baro_rate': -1920,
#    'geom_rate': -1952,
#    'squawk': '1722',
#    'emergency': 'none',
#    'category': 'A3',
#    'nav_qnh': 1013.6,
#    'nav_altitude_mcp': 6016,
#    'nav_heading': 130.78,
#    'lat': 34.473999,
#    'lon': -119.087313,
#    'nic': 8,
#    'rc': 186,
#    'seen_pos': 0.319,
#    'version': 2,
#    'nic_baro': 1,
#    'nac_p': 10,
#    'nac_v': 2,
#    'sil': 3,
#    'sil_type': 'perhour',
#    'gva': 2,
#    'sda': 2,
#    'alert': 0,
#    'spi': 0,
#    'mlat': [],
#    'tisb': [],
#    'messages': 55161281,
#    'seen': 0.3,
#    'rssi': -8.2},
#   {'hex': 'a240dc',
#    'type': 'adsb_icao',
#    'flight': 'SWA1872 ',
#    'r': 'N244WN',
#    't': 'B737',
#    'alt_baro': 30325,
#    'alt_geom': 31375,
#    'gs': 447.4,
#    'ias': 292,
#    'tas': 460,
#    'mach': 0.776,
#    'wd': 255,
#    'ws': 42,
#    'oat': -42,
#    'tat': -14,
#    'track': 329.37,
#    'track_rate': 0.0,
#    'roll': -0.18,
#    'mag_heading': 312.54,
#    'true_heading': 324.38,
#    'baro_rate': 1792,
#    'geom_rate': 1792,
#    'squawk': '5754',
#    'emergency': 'none',
#    'category': 'A3',
#    'nav_qnh': 1013.6,
#    'nav_altitude_mcp': 36000,
#    'nav_altitude_fms': 36000,
#    'nav_heading': 317.11,
#    'lat': 34.963989,
#    'lon': -119.05592,
#    'nic': 8,
#    'rc': 186,
#    'seen_pos': 0.456,
#    'version': 2,
#    'nic_baro': 1,
#    'nac_p': 8,
#    'nac_v': 1,
#    'sil': 3,
#    'sil_type': 'perhour',
#    'gva': 1,
#    'sda': 2,
#    'alert': 0,
#    'spi': 0,
#    'mlat': [],
#    'tisb': [],
#    'messages': 53585530,
#    'seen': 0.0,
#    'rssi': -12.4},
#   {'hex': 'aca608',
#    'type': 'adsb_icao',
#    'flight': 'FDX1818 ',
#    'r': 'N914FD',
#    't': 'B752',
#    'alt_baro': 20925,
#    'alt_geom': 21800,
#    'gs': 429.8,
#    'track': 242.72,
#    'baro_rate': -3520,
#    'squawk': '6066',
#    'emergency': 'none',
#    'category': 'A4',
#    'nav_qnh': 1013.6,
#    'nav_altitude_mcp': 11008,
#    'nav_heading': 231.33,
#    'nav_modes': ['vnav', 'tcas'],
#    'lat': 40.103714,
#    'lon': -119.049133,
#    'nic': 8,
#    'rc': 186,
#    'seen_pos': 0.104,
#    'version': 2,
#    'nic_baro': 1,
#    'nac_p': 9,
#    'nac_v': 1,
#    'sil': 3,
#    'sil_type': 'perhour',
#    'gva': 2,
#    'sda': 2,
#    'alert': 0,
#    'spi': 0,
#    'mlat': [],
#    'tisb': [],
#    'messages': 10870412,
#    'seen': 0.1,
#    'rssi': -10.0},
#   {'hex': 'a677a8',
#    'type': 'adsr_icao',
#    'flight': 'N5159U  ',
#    'r': 'N5159U',
#    't': 'C72R',
#    'alt_baro': 5400,
#    'alt_geom': 5500,
#    'gs': 99.4,
#    'track': 275.19,
#    'baro_rate': 320,
#    'geom_rate': 320,
#    'squawk': '6643',
#    'emergency': 'none',
#    'category': 'A1',
#    'lat': 47.400513,
#    'lon': -119.047096,
#    'nic': 8,
#    'rc': 186,
#    'seen_pos': 0.375,
#    'nic_baro': 0,
#    'nac_p': 9,
#    'nac_v': 2,
#    'sil': 3,
#    'sil_type': 'perhour',
#    'gva': 2,
#    'sda': 2,
#    'alert': 0,
#    'spi': 0,
#    'mlat': [],
#    'tisb': [],
#    'messages': 219162,
#    'seen': 0.4,
#    'rssi': -11.1},
#   {'hex': 'ac34a1',
#    'type': 'adsb_icao',
#    'flight': 'PCM7652 ',
#    'r': 'N886FE',
#    't': 'C208',
#    'alt_baro': 'ground',
#    'gs': 8.2,
#    'track': 213.75,
#    'squawk': '4746',
#    'emergency': 'none',
#    'category': 'A1',
#    'lat': 35.42569,
#    'lon': -119.045262,
#    'nic': 8,
#    'rc': 186,
#    'seen_pos': 1.363,
#    'version': 2,
#    'nac_p': 9,
#    'nac_v': 2,
#    'sil': 3,
#    'sil_type': 'perhour',
#    'sda': 2,
#    'mlat': [],
#    'tisb': [],
#    'messages': 6366461,
#    'seen': 1.4,
#    'rssi': -9.1},
#   {'hex': 'a3ba0f',
#    'type': 'adsb_icao',
#    'flight': 'N3393R  ',
#    'r': 'N3393R',
#    't': 'P28A',
#    'alt_baro': 10225,
#    'alt_geom': 10625,
#    'gs': 107.5,
#    'track': 225.75,
#    'geom_rate': 0,
#    'squawk': '6065',
#    'emergency': 'none',
#    'category': 'A1',
#    'lat': 40.026215,
#    'lon': -119.031982,
#    'nic': 9,
#    'rc': 75,
#    'seen_pos': 0.342,
#    'version': 2,
#    'nic_baro': 1,
#    'nac_p': 10,
#    'nac_v': 2,
#    'sil': 3,
#    'sil_type': 'perhour',
#    'gva': 2,
#    'sda': 2,
#    'alert': 0,
#    'spi': 0,
#    'mlat': [],
#    'tisb': [],
#    'messages': 496496,
#    'seen': 0.3,
#    'rssi': -16.6},
#   {'hex': 'a2fcf2',
#    'type': 'adsb_icao',
#    'flight': 'ASA1119 ',
#    'r': 'N292AK',
#    't': 'B739',
#    'alt_baro': 38000,
#    'alt_geom': 39075,
#    'gs': 447.9,
#    'ias': 246,
#    'tas': 440,
#    'mach': 0.776,
#    'wd': 243,
#    'ws': 35,
#    'oat': -61,
#    'tat': -36,
#    'track': 348.54,
#    'track_rate': 0.03,
#    'roll': 0.53,
#    'mag_heading': 331.88,
#    'true_heading': 344.13,
#    'baro_rate': 0,
#    'geom_rate': 32,
#    'squawk': '7776',
#    'emergency': 'none',
#    'category': 'A3',
#    'nav_qnh': 1013.6,
#    'nav_altitude_mcp': 38016,
#    'nav_heading': 331.88,
#    'lat': 37.052856,
#    'lon': -119.02623,
#    'nic': 8,
#    'rc': 186,
#    'seen_pos': 0.3,
#    'version': 2,
#    'nic_baro': 1,
#    'nac_p': 10,
#    'nac_v': 2,
#    'sil': 3,
#    'sil_type': 'perhour',
#    'gva': 2,
#    'sda': 2,
#    'alert': 0,
#    'spi': 0,
#    'mlat': [],
#    'tisb': [],
#    'messages': 67124545,
#    'seen': 0.3,
#    'rssi': -17.2},
#   {'hex': 'abd092',
#    'type': 'adsb_icao',
#    'flight': 'N860TT  ',
#    'r': 'N860TT',
#    't': 'B350',
#    'alt_baro': 6375,
#    'alt_geom': 6525,
#    'gs': 269.0,
#    'track': 277.05,
#    'baro_rate': -1472,
#    'squawk': '6751',
#    'emergency': 'none',
#    'category': 'A1',
#    'nav_qnh': 1018.4,
#    'nav_altitude_mcp': 992,
#    'nav_heading': 265.08,
#    'nav_modes': ['autopilot', 'vnav', 'lnav', 'tcas'],
#    'lat': 36.253719,
#    'lon': -118.999874,
#    'nic': 9,
#    'rc': 75,
#    'seen_pos': 0.419,
#    'version': 2,
#    'nic_baro': 1,
#    'nac_p': 10,
#    'nac_v': 2,
#    'sil': 3,
#    'sil_type': 'perhour',
#    'gva': 2,
#    'sda': 3,
#    'alert': 0,
#    'spi': 0,
#    'mlat': [],
#    'tisb': [],
#    'messages': 1790978,
#    'seen': 0.2,
#    'rssi': -9.0},
#   {'hex': 'a197f5',
#    'type': 'adsb_icao',
#    'flight': 'AMF1987 ',
#    'r': 'N201YW',
#    't': 'E120',
#    'alt_baro': 1925,
#    'alt_geom': 2100,
#    'gs': 199.8,
#    'track': 281.25,
#    'baro_rate': 0,
#    'geom_rate': 256,
#    'squawk': '4672',
#    'emergency': 'none',
#    'category': 'A2',
#    'lat': 46.185516,
#    'lon': -118.958688,
#    'nic': 9,
#    'rc': 75,
#    'seen_pos': 0.629,
#    'version': 2,
#    'nic_baro': 1,
#    'nac_p': 10,
#    'nac_v': 2,
#    'sil': 3,
#    'sil_type': 'perhour',
#    'gva': 2,
#    'sda': 2,
#    'alert': 0,
#    'spi': 0,
#    'mlat': [],
#    'tisb': ['baro_rate'],
#    'messages': 5318813,
#    'seen': 0.3,
#    'rssi': -4.1},
#   {'hex': 'acc176',
#    'type': 'adsb_icao',
#    'flight': 'N92069  ',
#    'r': 'N92069',
#    't': 'C182',
#    'alt_baro': 6825,
#    'alt_geom': 6975,
#    'gs': 138.5,
#    'track': 345.36,
#    'baro_rate': -704,
#    'squawk': '4753',
#    'emergency': 'none',
#    'category': 'A1',
#    'nav_qnh': 1018.4,
#    'nav_altitude_mcp': 1600,
#    'nav_heading': 334.69,
#    'lat': 34.991781,
#    'lon': -118.911095,
#    'nic': 9,
#    'rc': 75,
#    'seen_pos': 0.319,
#    'version': 2,
#    'nic_baro': 1,
#    'nac_p': 10,
#    'nac_v': 2,
#    'sil': 3,
#    'sil_type': 'perhour',
#    'gva': 2,
#    'sda': 2,
#    'alert': 0,
#    'spi': 0,
#    'mlat': [],
#    'tisb': [],
#    'messages': 2282361,
#    'seen': 0.2,
#    'rssi': -7.0},
#   {'hex': 'a1aa85',
#    'type': 'adsb_icao',
#    'flight': 'N206YT  ',
#    'r': 'N206YT',
#    't': 'B06',
#    'alt_baro': 700,
#    'alt_geom': 650,
#    'gs': 99.3,
#    'track': 341.2,
#    'geom_rate': 128,
#    'squawk': '1200',
#    'emergency': 'none',
#    'category': 'A7',
#    'lat': 35.103739,
#    'lon': -118.909435,
#    'nic': 9,
#    'rc': 75,
#    'seen_pos': 1.215,
#    'version': 2,
#    'nic_baro': 0,
#    'nac_p': 10,
#    'nac_v': 2,
#    'sil': 3,
#    'sil_type': 'perhour',
#    'gva': 2,
#    'sda': 2,
#    'alert': 0,
#    'spi': 0,
#    'mlat': [],
#    'tisb': [],
#    'messages': 108163,
#    'seen': 0.0,
#    'rssi': -19.9},
#   {'hex': 'adb6cb',
#    'type': 'adsb_icao',
#    'flight': 'CFS7804 ',
#    'r': 'N983FE',
#    't': 'C208',
#    'alt_baro': 5300,
#    'alt_geom': 5500,
#    'gs': 159.2,
#    'track': 39.39,
#    'baro_rate': 512,
#    'squawk': '4620',
#    'emergency': 'none',
#    'category': 'A1',
#    'lat': 46.494001,
#    'lon': -118.897133,
#    'nic': 9,
#    'rc': 75,
#    'seen_pos': 0.386,
#    'version': 2,
#    'nic_baro': 1,
#    'nac_p': 10,
#    'nac_v': 2,
#    'sil': 3,
#    'sil_type': 'perhour',
#    'gva': 2,
#    'sda': 2,
#    'alert': 0,
#    'spi': 0,
#    'mlat': [],
#    'tisb': [],
#    'messages': 3460371,
#    'seen': 0.4,
#    'rssi': -7.3},
#   {'hex': 'acbeac',
#    'type': 'adsb_icao',
#    'flight': 'PCM7694 ',
#    'r': 'N920FE',
#    't': 'C208',
#    'alt_baro': 7400,
#    'alt_geom': 7650,
#    'gs': 159.7,
#    'track': 98.28,
#    'baro_rate': 0,
#    'squawk': '4647',
#    'emergency': 'none',
#    'category': 'A1',
#    'lat': 34.276413,
#    'lon': -118.889065,
#    'nic': 9,
#    'rc': 75,
#    'seen_pos': 0.17,
#    'version': 2,
#    'nic_baro': 1,
#    'nac_p': 10,
#    'nac_v': 2,
#    'sil': 3,
#    'sil_type': 'perhour',
#    'gva': 2,
#    'sda': 2,
#    'alert': 0,
#    'spi': 0,
#    'mlat': [],
#    'tisb': [],
#    'messages': 7163635,
#    'seen': 0.2,
#    'rssi': -5.2},
#   {'hex': 'a30bce',
#    'type': 'adsb_icao',
#    'flight': 'ASA1055 ',
#    'r': 'N296AK',
#    't': 'B739',
#    'alt_baro': 26000,
#    'alt_geom': 26975,
#    'gs': 419.6,
#    'ias': 287,
#    'tas': 424,
#    'mach': 0.7,
#    'wd': 256,
#    'ws': 18,
#    'oat': -32,
#    'tat': -8,
#    'track': 330.44,
#    'track_rate': 0.0,
#    'roll': 0.0,
#    'mag_heading': 316.23,
#    'true_heading': 328.04,
#    'baro_rate': 1984,
#    'geom_rate': 1760,
#    'squawk': '1375',
#    'emergency': 'none',
#    'category': 'A3',
#    'nav_qnh': 1013.6,
#    'nav_altitude_mcp': 38016,
#    'nav_heading': 317.11,
#    'lat': 34.94588,
#    'lon': -118.887005,
#    'nic': 8,
#    'rc': 186,
#    'seen_pos': 0.375,
#    'version': 2,
#    'nic_baro': 1,
#    'nac_p': 10,
#    'nac_v': 2,
#    'sil': 3,
#    'sil_type': 'perhour',
#    'gva': 2,
#    'sda': 2,
#    'alert': 0,
#    'spi': 0,
#    'mlat': [],
#    'tisb': [],
#    'messages': 62974371,
#    'seen': 0.0,
#    'rssi': -7.3},
#   ...]}

# %%
flight_map = create_flight_map(flights_data)
flight_map.save('flights_visualizations/flights_map.html')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[37], line 2
#       1 flight_map = create_flight_map(flights_data)
# ----> 2 flight_map.save('flights_visualizations/flights_map.html')
#
# AttributeError: 'NoneType' object has no attribute 'save'

# %%
settings = Settings()


s1 = APIRouter(
    responses={
        status.HTTP_404_NOT_FOUND: {"description": "Not found"},
        status.HTTP_422_UNPROCESSABLE_ENTITY: {"description": "Something is wrong with the request"},
    },
    prefix="/api/s1",
    tags=["s1"],
)

# %%
import json


def read_flights_data(file_path):
    """
    Lê um arquivo JSON contendo dados de voos e retorna seu conteúdo.
    
    Parâmetros:
        file_path (str): Caminho para o arquivo JSON
        
    Retorna:
        dict: Dicionário contendo os dados dos voos
    """
    try:
        # Abrimos o arquivo em modo texto ('r') com codificação UTF-8
        with open(file_path, 'r', encoding='utf-8') as file:
            # json.load() converte o conteúdo JSON em um objeto Python
            data = json.load(file)
            return data
            
    except FileNotFoundError:
        # Caso o arquivo não seja encontrado
        print(f"Erro: O arquivo {file_path} não foi encontrado.")
        raise
        
    except json.JSONDecodeError:
        # Caso o arquivo não seja um JSON válido
        print(f"Erro: O arquivo {file_path} não contém um JSON válido.")
        raise
        
    except Exception as e:
        # Para outros tipos de erro que possam ocorrer
        print(f"Erro inesperado ao ler o arquivo: {str(e)}")
        raise

# %%
import json
import glob

@s1.post("/aircraft/download")
def download_data(
    file_limit: Annotated[
        int,
        Query(
            ...,
            description="""
    Limits the number of files to download.
    You must always start from the first the page returns and
    go in ascending order in order to correctly obtain the results.
    I'll test with increasing number of files starting from 100.""",
        ),
    ] = 100,
) -> str:
    """Downloads the `file_limit` files AS IS inside the folder data/20231101

    data: https://samples.adsbexchange.com/readsb-hist/2023/11/01/
    documentation: https://www.adsbexchange.com/version-2-api-wip/
        See "Trace File Fields" section

    Think about the way you organize the information inside the folder
    and the level of preprocessing you might need.

    To manipulate the data use any library you feel comfortable with.
    Just make sure to configure it in the `pyproject.toml` file
    so it can be installed using `poetry update`.


    TIP: always clean the download folder before writing again to avoid having old files.
    """
    download_dir = os.path.join(settings.raw_dir, "day=20231101")
    base_url = settings.source_url + "/2023/11/01/"

    os.makedirs(download_dir, exist_ok=True)
    # Remove todos os arquivos .gz dentro do diretório
    for f in glob.glob(os.path.join(download_dir, "*.gz")):
        os.remove(f)
    params = {
        "file_limit": file_limit,
    }

    headers = {
        "accept": "application/json",
    }

    number = 0
    for _ in range(file_limit):
        file_name = f"{str(number).zfill(6)}Z.json.gz"
        file_url = f"{base_url}/{file_name}"

        response = requests.get(file_url) # , params=params, headers=headers

        file_path = os.path.join(download_dir, file_name)
        print(f'i: {number} ')
        print(f'file name: {file_name} ')


        if response.status_code == 200:  
            print('response = 200')
            with open(file_path, 'w') as f:
                json.dump(response.json(), f)
                print('arquivo criado')
            number = number + 45 if number % 100 == 55 else number + 5

    

    return 'OK'

# %%
download_data(file_limit=100)
# Out:
# i: 0
# file name: 000000Z.json.gz
# response = 200
# arquivo criado
# i: 5
# file name: 000005Z.json.gz
# response = 200
# arquivo criado
# i: 10
# file name: 000010Z.json.gz
# response = 200
# arquivo criado
# i: 15
# file name: 000015Z.json.gz
# response = 200
# arquivo criado
# i: 20
# file name: 000020Z.json.gz
# response = 200
# arquivo criado
# i: 25
# file name: 000025Z.json.gz
# response = 200
# arquivo criado
# i: 30
# file name: 000030Z.json.gz
# response = 200
# arquivo criado
# i: 35
# file name: 000035Z.json.gz
# response = 200
# arquivo criado
# i: 40
# file name: 000040Z.json.gz
# response = 200
# arquivo criado
# i: 45
# file name: 000045Z.json.gz
# response = 200
# arquivo criado
# i: 50
# file name: 000050Z.json.gz
# response = 200
# arquivo criado
# i: 55
# file name: 000055Z.json.gz
# response = 200
# arquivo criado
# i: 100
# file name: 000100Z.json.gz
# response = 200
# arquivo criado
# i: 105
# file name: 000105Z.json.gz
# response = 200
# arquivo criado
# i: 110
# file name: 000110Z.json.gz
# response = 200
# arquivo criado
# i: 115
# file name: 000115Z.json.gz
# response = 200
# arquivo criado
# i: 120
# file name: 000120Z.json.gz
# response = 200
# arquivo criado
# i: 125
# file name: 000125Z.json.gz
# response = 200
# arquivo criado
# i: 130
# file name: 000130Z.json.gz
# response = 200
# arquivo criado
# i: 135
# file name: 000135Z.json.gz
# response = 200
# arquivo criado
# i: 140
# file name: 000140Z.json.gz
# response = 200
# arquivo criado
# i: 145
# file name: 000145Z.json.gz
# response = 200
# arquivo criado
# i: 150
# file name: 000150Z.json.gz
# response = 200
# arquivo criado
# i: 155
# file name: 000155Z.json.gz
# response = 200
# arquivo criado
# i: 200
# file name: 000200Z.json.gz
# response = 200
# arquivo criado
# i: 205
# file name: 000205Z.json.gz
# response = 200
# arquivo criado
# i: 210
# file name: 000210Z.json.gz
# response = 200
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[101], line 1
# ----> 1 download_data(file_limit=100)
#
# Cell In[100], line 63, in download_data(file_limit)
#      61 if response.status_code == 200:
#      62     print('response = 200')
# ---> 63     with open(file_path, 'w') as f:
#      64         json.dump(response.json(), f)
#      65         print('arquivo criado')
#
# File ~/Documents/BTS - Barcelona /Disciplinas/Big Data Infrastructure/big-data-infrastructure-exercises/.venv/lib/python3.11/site-packages/IPython/core/interactiveshell.py:310, in _modified_open(file, *args, **kwargs)
#     303 if file in {0, 1, 2}:
#     304     raise ValueError(
#     305         f"IPython won't let you open fd={file} by default "
#     306         "as it is likely to crash IPython. If you know what you are doing, "
#     307         "you can use builtins' open."
#     308     )
# --> 310 return io_open(file, *args, **kwargs)
#
# OSError: [Errno 28] No space left on device: '/Users/flor/Documents/BTS - Barcelona /Disciplinas/Big Data Infrastructure/big-data-infrastructure-exercises/data/raw/day=20231101/000210Z.json.gz'

# %%
import json


def read_flights_data(file_path):
    """
    Lê um arquivo JSON contendo dados de voos e retorna seu conteúdo.
    
    Parâmetros:
        file_path (str): Caminho para o arquivo JSON
        
    Retorna:
        dict: Dicionário contendo os dados dos voos
    """
    try:
        # Abrimos o arquivo em modo texto ('r') com codificação UTF-8
        with open(file_path, 'r', encoding='utf-8') as file:
            # json.load() converte o conteúdo JSON em um objeto Python
            data = json.load(file)
            return data
            
    except FileNotFoundError:
        # Caso o arquivo não seja encontrado
        print(f"Erro: O arquivo {file_path} não foi encontrado.")
        raise
        
    except json.JSONDecodeError:
        # Caso o arquivo não seja um JSON válido
        print(f"Erro: O arquivo {file_path} não contém um JSON válido.")
        raise
        
    except Exception as e:
        # Para outros tipos de erro que possam ocorrer
        print(f"Erro inesperado ao ler o arquivo: {str(e)}")
        raise

# %%
import json


def read_flights_data(file_path):
    """
    Lê um arquivo JSON contendo dados de voos e retorna seu conteúdo.
    
    Parâmetros:
        file_path (str): Caminho para o arquivo JSON
        
    Retorna:
        dict: Dicionário contendo os dados dos voos
    """
    try:
        # Abrimos o arquivo em modo texto ('r') com codificação UTF-8
        with open(file_path, 'r', encoding='utf-8') as file:
            # json.load() converte o conteúdo JSON em um objeto Python
            data = json.load(file)
            return data
            
    except FileNotFoundError:
        # Caso o arquivo não seja encontrado
        print(f"Erro: O arquivo {file_path} não foi encontrado.")
        raise
        
    except json.JSONDecodeError:
        # Caso o arquivo não seja um JSON válido
        print(f"Erro: O arquivo {file_path} não contém um JSON válido.")
        raise
        
    except Exception as e:
        # Para outros tipos de erro que possam ocorrer
        print(f"Erro inesperado ao ler o arquivo: {str(e)}")
        raise

# %%
def download_data(file_limit: Annotated[int, Query(...)] = 100) -> dict:
    download_dir = os.path.join(settings.raw_dir, "day=20231101")
    base_url = settings.source_url + "/2023/11/01"
    
    os.makedirs(download_dir, exist_ok=True)
    
    downloaded_files = []
    errors = []

    for i in range(0, file_limit*5, 5):  
        file_name = f"{i:06d}.json"
        file_url = f"{base_url}/{file_name}"
        
        try:
            response = requests.get(file_url)
            
            # Imprimir informações de debug
            print(f"URL: {file_url}")
            print(f"Status Code: {response.status_code}")
            print(f"Content Type: {response.headers.get('content-type', 'No content-type')}")
            print(f"First 200 chars of response: {response.text[:200]}\n")
            
            if response.status_code == 200:
                # Verificar se o conteúdo é realmente JSON
                try:
                    json_content = response.json()
                    # Se chegou aqui, é um JSON válido
                    file_path = os.path.join(download_dir, file_name)
                    with open(file_path, 'w') as f:
                        json.dump(json_content, f)
                    downloaded_files.append(file_name)
                except requests.exceptions.JSONDecodeError:
                    errors.append(f"File {file_name} is not valid JSON")
            else:
                errors.append(f"Failed to download {file_name}. Status code: {response.status_code}")
                
        except Exception as e:
            errors.append(f"Error processing {file_name}: {str(e)}")
    
    return {
        "message": f"Downloaded {len(downloaded_files)} files",
        "files": downloaded_files,
        "errors": errors
    }

# %%
import pandas as pd
import duckdb  

#@s1.post("/aircraft/prepare")
def prepare_data() -> str:
    """Prepara os dados para análise eficiente"""

    
    # Diretórios
    raw_dir = os.path.join(settings.raw_dir, "day=20231101")
    prepared_dir = os.path.join(settings.prepared_dir, "day=20231101")
    
    # Limpar diretório prepared
    if os.path.exists(prepared_dir):
        shutil.rmtree(prepared_dir)
    os.makedirs(prepared_dir)
    
    # Processar todos os arquivos
    all_data = []
    for file in glob.glob(os.path.join(raw_dir, "*.gz")):
        with open(file) as f:
            data = json.load(f)
            df = pd.DataFrame(data)
            all_data.append(df)
    
    # Combinar todos os dados
    df = pd.concat(all_data)
    
    # 1. Preparar dados de aeronaves (para list_aircraft)
    aircraft_info = df[['icao', 'registration', 'type']].drop_duplicates()
    aircraft_info = aircraft_info.sort_values('icao')
    
    # 2. Preparar posições (para get_aircraft_position)
    positions = df[['icao', 'timestamp', 'lat', 'lon']].sort_values(['icao', 'timestamp'])
    
    # 3. Preparar estatísticas (para get_aircraft_statistics)
    stats = df.groupby('icao').agg({
        'alt_baro': 'max',  # max_altitude_baro
        'gs': 'max',        # max_ground_speed
        'emergency': lambda x: any(x == '1')  # had_emergency
    }).reset_index()
    
    # Salvar em formato parquet (eficiente para consultas)
    aircraft_info.to_parquet(os.path.join(prepared_dir, 'aircraft_info.parquet'))
    positions.to_parquet(os.path.join(prepared_dir, 'positions.parquet'))
    stats.to_parquet(os.path.join(prepared_dir, 'statistics.parquet'))
    
    # Criar índices usando DuckDB para consultas mais rápidas
    con = duckdb.connect(os.path.join(prepared_dir, 'aircraft.db'))
    
    # Criar tabelas otimizadas
    con.execute("""
        CREATE TABLE aircraft AS 
        SELECT * FROM read_parquet('aircraft_info.parquet');
        
        CREATE TABLE positions AS 
        SELECT * FROM read_parquet('positions.parquet');
        
        CREATE TABLE stats AS 
        SELECT * FROM read_parquet('statistics.parquet');
        
        -- Criar índices
        CREATE INDEX idx_aircraft_icao ON aircraft(icao);
        CREATE INDEX idx_positions_icao ON positions(icao);
        CREATE INDEX idx_stats_icao ON stats(icao);
    """)
    con.close()
    
    return "OK"

# %%
prepare_data()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 prepare_data()
#
# Cell In[4], line 10, in prepare_data()
#       6 """Prepara os dados para análise eficiente"""
#       9 # Diretórios
# ---> 10 raw_dir = os.path.join(settings.raw_dir, "day=20231101")
#      11 prepared_dir = os.path.join(settings.prepared_dir, "day=20231101")
#      13 # Limpar diretório prepared
#
# NameError: name 'settings' is not defined

# %%
"""Prepara os dados para análise eficiente"""

raw_dir = os.path.join(settings.raw_dir, "day=20231101")
prepared_dir = os.path.join(settings.prepared_dir, "day=20231101")

os.makedirs(prepared_dir, exist_ok=True)
for f in glob.glob(os.path.join(prepared_dir, "*.gz")):
    os.remove(f)


# Processar todos os arquivos
all_data = []
for file in glob.glob(os.path.join(raw_dir, "*.gz")):
    with open(file) as f:
        data = json.load(f)
        # Pegar o timestamp do arquivo
        timestamp = data['now']
        aircraft_list = data['aircraft']
        # Criar DataFrame e adicionar o timestamp
        df = pd.DataFrame(aircraft_list)
        df['timestamp'] = timestamp
        all_data.append(df)

# Combinar todos os dados
df = pd.concat(all_data)

# data for list_aircraft

aircraft_info = df[['hex', 'r', 't']].drop_duplicates()
aircraft_info = aircraft_info.sort_values('hex')
aircraft_info.columns = ['icao', 'registration', 'type']  
aircraft_info.to_csv(os.path.join(prepared_dir, 'aircraft_info.csv'), index=False)


#data for get airline position

positions = df[['hex', 'timestamp', 'lat', 'lon']].sort_values(['hex', 'timestamp'])
positions.columns = ['icao', 'timestamp', 'lat', 'lon'] 
positions.to_csv(os.path.join(prepared_dir, 'positions.csv'), index=False)



#data for get_aircraft_statistics
df['emergency'] = df['emergency'].fillna('none')

df['had_emergency'] = df['emergency'] != 'none'
df['alt_baro'] = pd.to_numeric(df['alt_baro'], errors='coerce')
df['gs'] = pd.to_numeric(df['gs'], errors='coerce')
df['had_emergency'] = df['had_emergency'].astype(bool)

stats = df.groupby('hex').agg({
    'alt_baro': 'max',
    'gs': 'max',
    'had_emergency': 'max'
}).reset_index()

stats.columns = ['icao', 'max_altitude_baro', 'max_ground_speed', 'had_emergency']
stats.to_csv(os.path.join(prepared_dir, 'statistics.csv'), index=False)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 3
#       1 """Prepara os dados para análise eficiente"""
# ----> 3 raw_dir = os.path.join(Settings.raw_dir, "day=20231101")
#       4 prepared_dir = os.path.join(Settings.prepared_dir, "day=20231101")
#       6 os.makedirs(prepared_dir, exist_ok=True)
#
# File <frozen posixpath>:76, in join(a, *p)
#
# TypeError: expected str, bytes or os.PathLike object, not property

# %%
import os
def count_raw_files():
    raw_dir = '/Users/flor/Documents/BTS - Barcelona /Disciplinas/Big Data Infrastructure/big-data-infrastructure-exercises/data/raw/day=20231101'
    return len([f for f in os.listdir(raw_dir) if os.path.isfile(os.path.join(raw_dir, f))])


count_raw_files()
# Out:
# 715
